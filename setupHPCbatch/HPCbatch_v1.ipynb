# %% [markdown]
# # This is OK for desktop

# %% [markdown]
# Trying CMAP, use Python as that is the most recently updated package at CMAP\
# For now just testing out the code and figuring out how it works.
# ## Krista Longnecker, 14 June 2025
#
# Not bad for a first attempt, but I can close this now

# %%
import os, glob
import concurrent.futures
import pycmap
import sys
sys.path.append("../config")
from config import API_KEY
from settings import DATA_DIR, COLOCALIZED_DIR
from common import halt, makedir, environmental_datasets
import pandas as pd
import datetime
from dateutil.parser import parse

# %%
#set the easy/quick functions here
def cyano_csv_files(cyanoDir):
    """
    Returns a list of path to csv files that hold observations of cyanobacteria.
    KL note: leave name for now, though I am working on TOC/DOC data
    """
    return glob.glob(f"{cyanoDir}*.csv")


def add_env_columns(df, envs):
    """
    Adds new columns to the dataframe form each environmental variable.
    """
    for env in envs.values():
        for v in env.get("variables"):
            if v not in df.columns: df[v] = None
    return df
    

def add_env_temporal_coverage(api, envs):
    """
    Adds new entries to the envs dictionary indicating the temporal coverage of each environmental dataset.
    """
    for table, env in envs.items():
        df = api.query(f"SELECT MIN([time]) startTime, MAX([time]) endTime FROM {table}")
        if len(df) > 0:
            envs[table]["startTime"] = df.loc[0, "startTime"]
            envs[table]["endTime"] = df.loc[0, "endTime"]
    return envs

# %%
# %run collect.py
# Out:
# Downloading  ('tblBATS_Bottle', ['cruise_ID', 'TOC', 'phosphate'])  ...
# Downloading  ('tblGLODAP', ['cruise_expocode', 'toc', 'phosphate'])  ...
# Downloading  ('tblBATS_Bottle_Validation', ['cruise_ID', 'TOC', 'phosphate'])  ...
# Downloading  ('tblGeotraces_Seawater_IDP2021v2', ['cruise_id', 'DOC_D_CONC_BOTTLE', 'PHOSPHATE_D_CONC_BOTTLE'])  ...

# %%
#this is match (the query step is what takes the time
def match(df, api, envs, cyanoFile, rowCount):
    """
    Takes a single-row dataframe containing cyano observations and colocalizes with the 
    environmental variables included in the `envs` argument. The tolerance parametrs 
    are also included in the `envs` argument.
    """ 
    def get_month(dt):
        return parse(dt).month

    def shift_dt(dt, delta):
        delta = float(delta)
        dt = parse(dt)
        dt += datetime.timedelta(days=delta)
        return dt.strftime("%Y-%m-%d %H:%M:%S")

    def in_time_window(sourceDT, targetMinDT, targetMaxDT):
        targetMinDT = targetMinDT.split(".000Z")[0]
        targetMaxDT = targetMaxDT.split(".000Z")[0]
        return not (
                    parse(sourceDT) < parse(targetMinDT) or 
                    parse(sourceDT) > parse(targetMaxDT)
                    )

    def construc_query(table, env, t, lat, lon, depth):
        variables = env["variables"] 
        timeTolerance = env["tolerances"][0] 
        latTolerance = env["tolerances"][1] 
        lonTolerance = env["tolerances"][2]  
        depthTolerance = env["tolerances"][3]  
        hasDepth = env["hasDepth"] 
        isClimatology = env["isClimatology"]
        inTimeRange = True
        if not isClimatology:
            startTime = env["startTime"]
            endTime = env["endTime"]    
            inTimeRange = in_time_window(t, startTime, endTime)
        selectClause = "SELECT " + ", ".join([f"AVG({v}) {v}" for v in variables]) + " FROM " + table
        timeClause = f" WHERE [time] BETWEEN '{shift_dt(t, -timeTolerance)}' AND '{shift_dt(t, timeTolerance)}' "
        if not inTimeRange or isClimatology: timeClause = f" WHERE [month]={get_month(t)} "
        latClause = f" AND lat BETWEEN {lat-latTolerance} AND {lat+latTolerance} "
        lonClause = f" AND lon BETWEEN {lon-lonTolerance} AND {lon+lonTolerance} "
        depthClause = f" AND depth BETWEEN {depth-depthTolerance} AND {depth+depthTolerance} "
        if not hasDepth: depthClause = ""                
        return selectClause + timeClause + latClause + lonClause + depthClause        


    if len(df) != 1: halt(f"Invalid dataframe input.\nExpected a single row dataframe but received {len(df)} rows.")
    rowIndex = df.index.values[0]
    df.reset_index(drop=True, inplace=True)
    t= df.iloc[0]["time"]
    lat = df.iloc[0]["lat"]
    lon = df.iloc[0]["lon"] 
    depth = 0
    if 'depth' in df.columns: depth = df.iloc[0]["depth"]
    for table, env in envs.items():
        #KL turn off next line because it's make a rather large output file and I will not browse through it 6/18/2025
        #print(f"{rowIndex} / {rowCount-1}\n\t{datetime.datetime.now()}: Colocalizing {table} with {cyanoFile} ...")
        query = construc_query(table, env, t, lat, lon, depth)
        matchedEnv = api.query(query)
        if len(matchedEnv)>0:
            for v in env["variables"]: df.at[0, v] = matchedEnv.iloc[0][v] 
    return df

# %%
def main():
    """
    Iterates through the list of datasets and colocalizes them with the specified environmental variables.
    Colocalized datasets are stored in the "COLOCALIZED_DIR" as csv files.
    """
    def saveColocalizedCSV(df):
        df.to_csv(f"{COLOCALIZED_DIR}{os.path.basename(cyanoFile)}", index=False) 

    cyanoFiles = cyano_csv_files(DATA_DIR)
    api = pycmap.API(token=API_KEY)
    makedir(COLOCALIZED_DIR)
    envs = environmental_datasets()        
    envs = add_env_temporal_coverage(api, envs)

    for cyanoFile in cyanoFiles:
        df = pd.read_csv(cyanoFile)
        df = add_env_columns(df, envs)
        dfs = [df.loc[i].to_frame().T for i in range(len(df))]
        colocalizedDF  = pd.DataFrame({})
        with concurrent.futures.ThreadPoolExecutor() as executor:
            futureObjs = executor.map(match, dfs, [api] * len(dfs), [envs] * len(dfs), [cyanoFile] * len(dfs), [len(dfs)] * len(dfs))
            for fo in futureObjs:
                if len(colocalizedDF) < 1:
                    colocalizedDF = fo
                else:
                    colocalizedDF = pd.concat([colocalizedDF, fo], ignore_index=True)  
        saveColocalizedCSV(colocalizedDF)

# %%
# break out into pieces, then add new script to assemble each colocalized dataframe

# %%
cyanoFiles = cyano_csv_files(DATA_DIR)

# %%
cyanoFiles
# Out:
# ['./data\\tblBATS_Bottle.csv',
#  './data\\tblBATS_Bottle_Validation.csv',
#  './data\\tblGeotraces_Seawater_IDP2021v2.csv',
#  './data\\tblGLODAP.csv']

# %%
api = pycmap.API(token=API_KEY)
makedir(COLOCALIZED_DIR)
envs = environmental_datasets()        
envs = add_env_temporal_coverage(api, envs)

# %%
envs
# Out:
# {'tblCHL_REP': {'variables': ['chl'],
#   'tolerances': [4, 0.25, 0.25, 5],
#   'hasDepth': False,
#   'isClimatology': False,
#   'startTime': '1998-01-01T00:00:00.000Z',
#   'endTime': '2018-06-26T00:00:00.000Z'},
#  'tblPisces_NRT': {'variables': ['NO3', 'PO4', 'Fe', 'O2', 'Si', 'PP'],
#   'tolerances': [4, 0.5, 0.5, 5],
#   'hasDepth': True,
#   'isClimatology': False,
#   'startTime': '2011-12-31T00:00:00.000Z',
#   'endTime': '2019-04-27T00:00:00.000Z'},
#  'tblWOA_Climatology': {'variables': ['density_WOA_clim',
#    'salinity_WOA_clim',
#    'nitrate_WOA_clim',
#    'phosphate_WOA_clim',
#    'silicate_WOA_clim',
#    'oxygen_WOA_clim'],
#   'tolerances': [1, 0.75, 0.75, 5],
#   'hasDepth': True,
#   'isClimatology': True}}

# %%
def get_month(dt):
    return parse(dt).month

def shift_dt(dt, delta):
    delta = float(delta)
    dt = parse(dt)
    dt += datetime.timedelta(days=delta)
    return dt.strftime("%Y-%m-%d %H:%M:%S")

def in_time_window(sourceDT, targetMinDT, targetMaxDT):
    targetMinDT = targetMinDT.split(".000Z")[0]
    targetMaxDT = targetMaxDT.split(".000Z")[0]
    return not (
                parse(sourceDT) < parse(targetMinDT) or 
                parse(sourceDT) > parse(targetMaxDT)
                )

def construc_query(table, env, t, lat, lon, depth):
    variables = env["variables"] 
    timeTolerance = env["tolerances"][0] 
    latTolerance = env["tolerances"][1] 
    lonTolerance = env["tolerances"][2]  
    depthTolerance = env["tolerances"][3]  
    hasDepth = env["hasDepth"] 
    isClimatology = env["isClimatology"]
    inTimeRange = True
    if not isClimatology:
        startTime = env["startTime"]
        endTime = env["endTime"]    
        inTimeRange = in_time_window(t, startTime, endTime)
    selectClause = "SELECT " + ", ".join([f"AVG({v}) {v}" for v in variables]) + " FROM " + table
    timeClause = f" WHERE [time] BETWEEN '{shift_dt(t, -timeTolerance)}' AND '{shift_dt(t, timeTolerance)}' "
    if not inTimeRange or isClimatology: timeClause = f" WHERE [month]={get_month(t)} "
    latClause = f" AND lat BETWEEN {lat-latTolerance} AND {lat+latTolerance} "
    lonClause = f" AND lon BETWEEN {lon-lonTolerance} AND {lon+lonTolerance} "
    depthClause = f" AND depth BETWEEN {depth-depthTolerance} AND {depth+depthTolerance} "
    if not hasDepth: depthClause = ""                
    return selectClause + timeClause + latClause + lonClause + depthClause

# %%
cyanoFiles[1]
# Out:
# './data\\tblBATS_Bottle_Validation.csv'

# %%
cyanoFile = cyanoFiles[1]

# %%
df = pd.read_csv(cyanoFile)
df = add_env_columns(df, envs)
dfs = [df.loc[i].to_frame().T for i in range(len(df))]
colocalizedDF  = pd.DataFrame({})

# %%
rowIndex = df.index.values[0]
df.reset_index(drop=True, inplace=True)
t= df.iloc[0]["time"]
lat = df.iloc[0]["lat"]
lon = df.iloc[0]["lon"] 
depth = 0

# %%
if 'depth' in df.columns: depth = df.iloc[0]["depth"]

# %%
df
# Out:
#                       time     lat     lon  depth   cruise_ID  TOC  phosphate  \
# 0      1991-04-29T14:30:00  32.165 -64.503    2.4  5000100112  NaN        NaN
# 1      1991-04-29T14:30:00  32.165 -64.503   24.2  5000100111  NaN        NaN
# 2      1991-04-29T14:30:00  32.165 -64.503   50.4  5000100110  NaN        NaN
# 3      1991-04-29T14:30:00  32.165 -64.503   73.9  5000100109  NaN        NaN
# 4      1991-04-29T14:30:00  32.165 -64.503   99.7  5000100108  NaN        NaN
# ...                    ...     ...     ...    ...         ...  ...        ...
# 14934  2022-06-15T22:34:00  19.669 -65.965  150.2  5005902514  NaN        NaN
# 14935  2022-06-15T22:34:00  19.669 -65.965  200.6  5005902515  NaN       0.11
# 14936  2022-06-15T22:34:00  19.669 -65.965  301.6  5005902516  NaN       0.32
# 14937  2022-06-15T22:34:00  19.669 -65.965  401.6  5005902517  NaN       0.58
# 14938  2022-06-15T22:34:00  19.669 -65.965  700.3  5005902518  NaN       1.64
#
#         chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
# 0      None  None  None  None  None  None  None             None
# 1      None  None  None  None  None  None  None             None
# 2      None  None  None  None  None  None  None             None
# 3      None  None  None  None  None  None  None             None
# 4      None  None  None  None  None  None  None             None
# ...     ...   ...   ...   ...   ...   ...   ...              ...
# 14934  None  None  None  None  None  None  None             None
# 14935  None  None  None  None  None  None  None             None
# 14936  None  None  None  None  None  None  None             None
# 14937  None  None  None  None  None  None  None             None
# 14938  None  None  None  None  None  None  None             None
#
#       salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
# 0                  None             None               None              None
# 1                  None             None               None              None
# 2                  None             None               None              None
# 3                  None             None               None              None
# 4                  None             None               None              None
# ...                 ...              ...                ...               ...
# 14934              None             None               None              None
# 14935              None             None               None              None
# 14936              None             None               None              None
# 14937              None             None               None              None
# 14938              None             None               None              None
#
#       oxygen_WOA_clim
# 0                None
# 1                None
# 2                None
# 3                None
# 4                None
# ...               ...
# 14934            None
# 14935            None
# 14936            None
# 14937            None
# 14938            None
#
# [14939 rows x 20 columns]

# %%
envs.items
# Out:
# <function dict.items()>

# %%
envs
# Out:
# {'tblCHL_REP': {'variables': ['chl'],
#   'tolerances': [4, 0.25, 0.25, 5],
#   'hasDepth': False,
#   'isClimatology': False,
#   'startTime': '1998-01-01T00:00:00.000Z',
#   'endTime': '2018-06-26T00:00:00.000Z'},
#  'tblPisces_NRT': {'variables': ['NO3', 'PO4', 'Fe', 'O2', 'Si', 'PP'],
#   'tolerances': [4, 0.5, 0.5, 5],
#   'hasDepth': True,
#   'isClimatology': False,
#   'startTime': '2011-12-31T00:00:00.000Z',
#   'endTime': '2019-04-27T00:00:00.000Z'},
#  'tblWOA_Climatology': {'variables': ['density_WOA_clim',
#    'salinity_WOA_clim',
#    'nitrate_WOA_clim',
#    'phosphate_WOA_clim',
#    'silicate_WOA_clim',
#    'oxygen_WOA_clim'],
#   'tolerances': [1, 0.75, 0.75, 5],
#   'hasDepth': True,
#   'isClimatology': True}}

# %%
env = envs[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 env = envs[1]
#
# KeyError: 1

# %%
type(envs)
# Out:
# dict

# %%
next(iter(envs))
# Out:
# 'tblCHL_REP'

# %%
from IPython import embed #then add embed() where I want to stop

# %%
for table, env in envs.items():
    query = construc_query(table, env, t, lat, lon, depth)
    matchedEnv = api.query(query)
    if len(matchedEnv)>0:
        for v in env["variables"]: df.at[0, v] = matchedEnv.iloc[0][v]

# %%
df
# Out:
#                       time     lat     lon  depth   cruise_ID  TOC  phosphate  \
# 0      1991-04-29T14:30:00  32.165 -64.503    2.4  5000100112  NaN        NaN
# 1      1991-04-29T14:30:00  32.165 -64.503   24.2  5000100111  NaN        NaN
# 2      1991-04-29T14:30:00  32.165 -64.503   50.4  5000100110  NaN        NaN
# 3      1991-04-29T14:30:00  32.165 -64.503   73.9  5000100109  NaN        NaN
# 4      1991-04-29T14:30:00  32.165 -64.503   99.7  5000100108  NaN        NaN
# ...                    ...     ...     ...    ...         ...  ...        ...
# 14934  2022-06-15T22:34:00  19.669 -65.965  150.2  5005902514  NaN        NaN
# 14935  2022-06-15T22:34:00  19.669 -65.965  200.6  5005902515  NaN       0.11
# 14936  2022-06-15T22:34:00  19.669 -65.965  301.6  5005902516  NaN       0.32
# 14937  2022-06-15T22:34:00  19.669 -65.965  401.6  5005902517  NaN       0.58
# 14938  2022-06-15T22:34:00  19.669 -65.965  700.3  5005902518  NaN       1.64
#
#             chl       NO3       PO4        Fe          O2        Si        PP  \
# 0      0.135655  1.939887  0.158448  0.000035  234.741243  2.917146  0.023538
# 1          None      None      None      None        None      None      None
# 2          None      None      None      None        None      None      None
# 3          None      None      None      None        None      None      None
# 4          None      None      None      None        None      None      None
# ...         ...       ...       ...       ...         ...       ...       ...
# 14934      None      None      None      None        None      None      None
# 14935      None      None      None      None        None      None      None
# 14936      None      None      None      None        None      None      None
# 14937      None      None      None      None        None      None      None
# 14938      None      None      None      None        None      None      None
#
#       density_WOA_clim salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim  \
# 0            26.057992         36.622066          0.10174           0.016469
# 1                 None              None             None               None
# 2                 None              None             None               None
# 3                 None              None             None               None
# 4                 None              None             None               None
# ...                ...               ...              ...                ...
# 14934             None              None             None               None
# 14935             None              None             None               None
# 14936             None              None             None               None
# 14937             None              None             None               None
# 14938             None              None             None               None
#
#       silicate_WOA_clim oxygen_WOA_clim
# 0              0.644847        5.308658
# 1                  None            None
# 2                  None            None
# 3                  None            None
# 4                  None            None
# ...                 ...             ...
# 14934              None            None
# 14935              None            None
# 14936              None            None
# 14937              None            None
# 14938              None            None
#
# [14939 rows x 20 columns]

# %%
rowIndex = df.index.values[0]

# %%
rowIndex
# Out:
# np.int64(0)

# %%
df.index.values[0:4]
# Out:
# array([0, 1, 2, 3])

# %%
dfs
# Out:
# [                  time     lat     lon depth   cruise_ID  TOC phosphate   chl  \
#  0  1991-04-29T14:30:00  32.165 -64.503   2.4  5000100112  NaN       NaN  None
#
#      NO3   PO4    Fe    O2    Si    PP density_WOA_clim salinity_WOA_clim  \
#  0  None  None  None  None  None  None             None              None
#
#    nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim oxygen_WOA_clim
#  0             None               None              None            None  ,
#                    time     lat     lon depth   cruise_ID  TOC phosphate   chl  \
#  1  1991-04-29T14:30:00  32.165 -64.503  24.2  5000100111  NaN       NaN  None
#
#      NO3   PO4    Fe    O2    Si    PP density_WOA_clim salinity_WOA_clim  \
#  1  None  None  None  None  None  None             None              None
#
#    nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim oxygen_WOA_clim
#  1             None               None              None            None  ,
#                    time     lat     lon depth   cruise_ID  TOC phosphate   chl  \
#  2  1991-04-29T14:30:00  32.165 -64.503  50.4  5000100110  NaN       NaN  None
#
#      NO3   PO4    Fe    O2    Si    PP density_WOA_clim salinity_WOA_clim  \
#  2  None  None  None  None  None  None             None              None
#
#    nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim oxygen_WOA_clim
#  2             None               None              None            None  ,
#                    time     lat     lon depth   cruise_ID  TOC phosphate   chl  \
#  3  1991-04-29T14:30:00  32.165 -64.503  73.9  5000100109  NaN       NaN  None
#
#      NO3   PO4    Fe    O2    Si    PP density_WOA_clim salinity_WOA_clim  \
#  3  None  None  None  None  None  None             None              None
#
#    nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim oxygen_WOA_clim
#  3             None               None              None            None  ,
#                    time     lat     lon depth   cruise_ID  TOC phosphate   chl  \
#  4  1991-04-29T14:30:00  32.165 -64.503  99.7  5000100108  NaN       NaN  None
#
#      NO3   PO4    Fe    O2    Si    PP density_WOA_clim salinity_WOA_clim  \
#  4  None  None  None  None  None  None             None              None
#
#    nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim oxygen_WOA_clim
#  4             None               None              None            None  ,
#                    time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  5  1991-04-29T14:30:00  32.165 -64.503  199.8  5000100106  NaN       NaN
#
#      chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  5  None  None  None  None  None  None  None             None
#
#    salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  5              None             None               None              None
#
#    oxygen_WOA_clim
#  5            None  ,
#                    time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  6  1991-04-29T14:30:00  32.165 -64.503  299.9  5000100105  NaN       NaN
#
#      chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  6  None  None  None  None  None  None  None             None
#
#    salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  6              None             None               None              None
#
#    oxygen_WOA_clim
#  6            None  ,
#                    time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  7  1991-04-29T14:30:00  32.165 -64.503  500.4  5000100104  NaN       NaN
#
#      chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  7  None  None  None  None  None  None  None             None
#
#    salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  7              None             None               None              None
#
#    oxygen_WOA_clim
#  7            None  ,
#                    time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  8  1991-04-29T14:30:00  32.165 -64.503  699.9  5000100103  NaN       NaN
#
#      chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  8  None  None  None  None  None  None  None             None
#
#    salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  8              None             None               None              None
#
#    oxygen_WOA_clim
#  8            None  ,
#                    time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  9  1991-04-29T14:30:00  32.165 -64.503  900.3  5000100102  NaN       NaN
#
#      chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  9  None  None  None  None  None  None  None             None
#
#    salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  9              None             None               None              None
#
#    oxygen_WOA_clim
#  9            None  ,
#                     time     lat     lon depth   cruise_ID  TOC phosphate  \
#  10  1991-04-29T19:00:00  31.738 -64.259   2.6  5000100212  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  10  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  10              None             None               None              None
#
#     oxygen_WOA_clim
#  10            None  ,
#                     time     lat     lon depth   cruise_ID  TOC phosphate  \
#  11  1991-04-29T19:00:00  31.738 -64.259  24.4  5000100211  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  11  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  11              None             None               None              None
#
#     oxygen_WOA_clim
#  11            None  ,
#                     time     lat     lon depth   cruise_ID  TOC phosphate  \
#  12  1991-04-29T19:00:00  31.738 -64.259  50.0  5000100210  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  12  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  12              None             None               None              None
#
#     oxygen_WOA_clim
#  12            None  ,
#                     time     lat     lon depth   cruise_ID  TOC phosphate  \
#  13  1991-04-29T19:00:00  31.738 -64.259  74.1  5000100209  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  13  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  13              None             None               None              None
#
#     oxygen_WOA_clim
#  13            None  ,
#                     time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  14  1991-04-29T19:00:00  31.738 -64.259  100.4  5000100208  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  14  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  14              None             None               None              None
#
#     oxygen_WOA_clim
#  14            None  ,
#                     time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  15  1991-04-29T19:00:00  31.738 -64.259  199.1  5000100206  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  15  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  15              None             None               None              None
#
#     oxygen_WOA_clim
#  15            None  ,
#                     time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  16  1991-04-29T19:00:00  31.738 -64.259  301.0  5000100205  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  16  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  16              None             None               None              None
#
#     oxygen_WOA_clim
#  16            None  ,
#                     time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  17  1991-04-29T19:00:00  31.738 -64.259  502.4  5000100204  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  17  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  17              None             None               None              None
#
#     oxygen_WOA_clim
#  17            None  ,
#                     time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  18  1991-04-29T19:00:00  31.738 -64.259  702.2  5000100203  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  18  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  18              None             None               None              None
#
#     oxygen_WOA_clim
#  18            None  ,
#                     time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  19  1991-04-29T19:00:00  31.738 -64.259  899.5  5000100202  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  19  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  19              None             None               None              None
#
#     oxygen_WOA_clim
#  19            None  ,
#                     time     lat     lon depth   cruise_ID  TOC phosphate  \
#  20  1991-04-30T03:45:00  31.409 -63.917   3.4  5000100512  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  20  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  20              None             None               None              None
#
#     oxygen_WOA_clim
#  20            None  ,
#                     time     lat     lon depth   cruise_ID  TOC phosphate  \
#  21  1991-04-30T03:45:00  31.409 -63.917  25.2  5000100511  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  21  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  21              None             None               None              None
#
#     oxygen_WOA_clim
#  21            None  ,
#                     time     lat     lon depth   cruise_ID  TOC phosphate  \
#  22  1991-04-30T03:45:00  31.409 -63.917  51.3  5000100510  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  22  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  22              None             None               None              None
#
#     oxygen_WOA_clim
#  22            None  ,
#                     time     lat     lon depth   cruise_ID  TOC phosphate  \
#  23  1991-04-30T03:45:00  31.409 -63.917  74.3  5000100509  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  23  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  23              None             None               None              None
#
#     oxygen_WOA_clim
#  23            None  ,
#                     time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  24  1991-04-30T03:45:00  31.409 -63.917  100.2  5000100508  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  24  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#
NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  46  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  46              None             None               None              None
#
#     oxygen_WOA_clim
#  46            None  ,
#                     time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  47  1991-04-30T10:01:00  31.416 -64.665  151.1  5000100707  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  47  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  47              None             None               None              None
#
#     oxygen_WOA_clim
#  47            None  ,
#                     time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  48  1991-04-30T10:01:00  31.416 -64.665  201.2  5000100706  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  48  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  48              None             None               None              None
#
#     oxygen_WOA_clim
#  48            None  ,
#                     time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  49  1991-04-30T10:01:00  31.416 -64.665  300.3  5000100705  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  49  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  49              None             None               None              None
#
#     oxygen_WOA_clim
#  49            None  ,
#                     time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  50  1991-04-30T10:01:00  31.416 -64.665  503.1  5000100704  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  50  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  50              None             None               None              None
#
#     oxygen_WOA_clim
#  50            None  ,
#                     time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  51  1991-04-30T10:01:00  31.416 -64.665  701.4  5000100703  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  51  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  51              None             None               None              None
#
#     oxygen_WOA_clim
#  51            None  ,
#                     time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  52  1991-04-30T10:01:00  31.416 -64.665  903.2  5000100702  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  52  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  52              None             None               None              None
#
#     oxygen_WOA_clim
#  52            None  ,
#                     time     lat     lon depth   cruise_ID  TOC phosphate  \
#  53  1991-05-01T04:08:00  31.755 -64.577   2.8  5000101412  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  53  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  53              None             None               None              None
#
#     oxygen_WOA_clim
#  53            None  ,
#                     time     lat     lon depth   cruise_ID  TOC phosphate  \
#  54  1991-05-01T04:08:00  31.755 -64.577  25.1  5000101411  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  54  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  54              None             None               None              None
#
#     oxygen_WOA_clim
#  54            None  ,
#                     time     lat     lon depth   cruise_ID  TOC phosphate  \
#  55  1991-05-01T04:08:00  31.755 -64.577  51.2  5000101410  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  55  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  55              None             None               None              None
#
#     oxygen_WOA_clim
#  55            None  ,
#                     time     lat     lon depth   cruise_ID  TOC phosphate  \
#  56  1991-05-01T04:08:00  31.755 -64.577  74.7  5000101409  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  56  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  56              None             None               None              None
#
#     oxygen_WOA_clim
#  56            None  ,
#                     time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  57  1991-05-01T04:08:00  31.755 -64.577  100.1  5000101408  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  57  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  57              None             None               None              None
#
#     oxygen_WOA_clim
#  57            None  ,
#                     time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  58  1991-05-01T04:08:00  31.755 -64.577  149.8  5000101407  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  58  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  58              None             None               None              None
#
#     oxygen_WOA_clim
#  58            None  ,
#                     time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  59  1991-05-01T04:08:00  31.755 -64.577  200.6  5000101406  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  59  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  59              None             None               None              None
#
#     oxygen_WOA_clim
#  59            None  ,
#                     time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  60  1991-05-01T04:08:00  31.755 -64.577  298.6  5000101405  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  60  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  60              None             None               None              None
#
#     oxygen_WOA_clim
#  60            None  ,
#                     time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  61  1991-05-01T04:08:00  31.755 -64.577  500.0  5000101404  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  61  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  61              None             None               None              None
#
#     oxygen_WOA_clim
#  61            None  ,
#                     time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  62  1991-05-01T04:08:00  31.755 -64.577  700.5  5000101403  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  62  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  62              None             None               None              None
#
#     oxygen_WOA_clim
#  62            None  ,
#                     time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  63  1991-05-01T04:08:00  31.755 -64.577  900.2  5000101402  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  63  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  63              None             None               None              None
#
#     oxygen_WOA_clim
#  63            None  ,
#                     time     lat     lon depth   cruise_ID  TOC phosphate  \
#  64  1991-05-01T07:24:00  32.085 -64.578   2.4  5000101512  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  64  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  64              None             None               None              None
#
#     oxygen_WOA_clim
#  64            None  ,
#                     time     lat     lon depth   cruise_ID  TOC phosphate  \
#  65  1991-05-01T07:24:00  32.085 -64.578  27.4  5000101511  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  65  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  65              None             None               None              None
#
#     oxygen_WOA_clim
#  65            None  ,
#                     time     lat     lon depth   cruise_ID  TOC phosphate  \
#  66  1991-05-01T07:24:00  32.085 -64.578  49.4  5000101510  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  66  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  66              None             None               None              None
#
#     oxygen_WOA_clim
#  66            None  ,
#                     time     lat     lon depth   cruise_ID  TOC phosphate  \
#  67  1991-05-01T07:24:00  32.085 -64.578  74.1  5000101509  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  67  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  67              None             None               None              None
#
#     oxygen_WOA_clim
#  67            None  ,
#                     time     lat     lon depth   cruise_ID  TOC phosphate  \
#  68  1991-05-01T07:24:00  32.085 -64.578  99.8  5000101508  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  68  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  68              None             None               None              None
#
#     oxygen_WOA_clim
#  68            None  ,
#                     time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  69  1991-05-01T07:24:00  32.085 -64.578  150.1  5000101507  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  69  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  69              None             None               None              None
#
#     oxygen_WOA_clim
#  69            None  ,
#                     time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  70  1991-05-01T07:24:00  32.085 -64.578  201.0  5000101506  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  70  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  70              None             None               None              None
#
#     oxygen_WOA_clim
#  70            None  ,
#                     time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  71  1991-05-01T07:24:00  32.085 -64.578  303.1  5000101505  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  71  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  71              None             None               None              None
#
#     oxygen_WOA_clim
#  71            None  ,
#                     time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  72  1991-05-01T07:24:00  32.085 -64.578  502.1  5000101504  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  72  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  72              None             None               None              None
#
#     oxygen_WOA_clim
#  72            None  ,
#                     time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  73  1991-05-01T07:24:00  32.085 -64.578  706.3  5000101503  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  73  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  73              None             None               None              None
#
#     oxygen_WOA_clim
#  73            None  ,
#                     time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  74  1991-05-01T07:24:00  32.085 -64.578  901.8  5000101502  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  74  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  74              None             None               None              None
#
#     oxygen_WOA_clim
#  74            None  ,
#                     time    lat     lon depth   cruise_ID  TOC phosphate   chl  \
#  75  1991-05-01T10:20:00  31.08 -64.247   4.1  5000101612  NaN       NaN  None
#
#       NO3   PO4    Fe    O2    Si    PP density_WOA_clim salinity_WOA_clim  \
#  75  None  None  None  None  None  None             None              None
#
#     nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim oxygen_WOA_clim
#  75             None               None              None            None  ,
#                     time    lat     lon depth   cruise_ID  TOC phosphate   chl  \
#  76  1991-05-01T10:20:00  31.08 -64.247  26.4  5000101611  NaN       NaN  None
#
#       NO3   PO4    Fe    O2    Si    PP density_WOA_clim salinity_WOA_clim  \
#  76  None  None  None  None  None  None             None              None
#
#     nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim oxygen_WOA_clim
#  76             None               None              None            None  ,
#                     time    lat     lon depth   cruise_ID  TOC phosphate   chl  \
#  77  1991-05-01T10:20:00  31.08 -64.247  50.2  5000101610  NaN       NaN  None
#
#       NO3   PO4    Fe    O2    Si    PP density_WOA_clim salinity_WOA_clim  \
#  77  None  None  None  None  None  None             None              None
#
#     nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim oxygen_WOA_clim
#  77             None               None              None            None  ,
#                     time    lat     lon depth   cruise_ID  TOC phosphate   chl  \
#  78  1991-05-01T10:20:00  31.08 -64.247  74.8  5000101609  NaN       NaN  None
#
#       NO3   PO4    Fe    O2    Si    PP density_WOA_clim salinity_WOA_clim  \
#  78  None  None  None  None  None  None             None              None
#
#     nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim oxygen_WOA_clim
#  78             None               None              None            None  ,
#                     time    lat     lon  depth   cruise_ID  TOC phosphate  \
#  79  1991-05-01T10:20:00  31.08 -64.247  103.6  5000101608  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  79  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  79              None             None               None              None
#
#     oxygen_WOA_clim
#  79            None  ,
#                     time    lat     lon  depth   cruise_ID  TOC phosphate  \
#  80  1991-05-01T10:20:00  31.08 -64.247  152.3  5000101607  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  80  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  80              None             None               None              None
#
#     oxygen_WOA_clim
#  80            None  ,
#                     time    lat     lon  depth   cruise_ID  TOC phosphate  \
#  81  1991-05-01T10:20:00  31.08 -64.247  200.0  5000101606  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  81  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  81              None             None               None              None
#
#     oxygen_WOA_clim
#  81            None  ,
#                     time    lat     lon  depth   cruise_ID  TOC phosphate  \
#  82  1991-05-01T10:20:00  31.08 -64.247  301.1  5000101605  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  82  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  82              None             None               None              None
#
#     oxygen_WOA_clim
#  82            None  ,
#                     time    lat     lon  depth   cruise_ID  TOC phosphate  \
#  83  1991-05-01T10:20:00  31.08 -64.247  501.1  5000101604  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  83  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  83              None             None               None              None
#
#     oxygen_WOA_clim
#  83            None  ,
#                     time    lat     lon  depth   cruise_ID  TOC phosphate  \
#  84  1991-05-01T10:20:00  31.08 -64.247  700.2  5000101602  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  84  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  84              None             None               None              None
#
#     oxygen_WOA_clim
#  84            None  ,
#                     time    lat     lon  depth   cruise_ID  TOC phosphate  \
#  85  1991-05-01T10:20:00  31.08 -64.247  700.9  5000101603  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  85  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  85              None             None               None              None
#
#     oxygen_WOA_clim
#  85            None  ,
#                     time    lat     lon  depth   cruise_ID  TOC phosphate  \
#  86  1991-05-01T10:20:00  31.08 -64.247  701.0  5000101601  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  86  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  86              None             None               None              None
#
#     oxygen_WOA_clim
#  86            None  ,
#                     time     lat     lon depth   cruise_ID  TOC phosphate  \
#  87  1991-05-02T15:55:00  32.082 -64.582   4.0  5000101712  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  87  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  87              None             None               None              None
#
#     oxygen_WOA_clim
#  87            None  ,
#                     time     lat     lon depth   cruise_ID  TOC phosphate  \
#  88  1991-05-02T15:55:00  32.082 -64.582  24.8  5000101711  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  88  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  88              None             None               None              None
#
#     oxygen_WOA_clim
#  88            None  ,
#                     time     lat     lon depth   cruise_ID  TOC phosphate  \
#  89  1991-05-02T15:55:00  32.082 -64.582  49.3  5000101710  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  89  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  89              None             None               None              None
#
#     oxygen_WOA_clim
#  89            None  ,
#                     time     lat     lon depth   cruise_ID  TOC phosphate  \
#  90  1991-05-02T15:55:00  32.082 -64.582  73.8  5000101709  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  90  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  90              None             None               None              None
#
#     oxygen_WOA_clim
#  90            None  ,
#                     time     lat     lon depth   cruise_ID  TOC phosphate  \
#  91  1991-05-02T15:55:00  32.082 -64.582  99.9  5000101708  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  91  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  91              None             None               None              None
#
#     oxygen_WOA_clim
#  91            None  ,
#                     time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  92  1991-05-02T15:55:00  32.082 -64.582  151.1  5000101707  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  92  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  92              None             None               None              None
#
#     oxygen_WOA_clim
#  92            None  ,
#                     time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  93  1991-05-02T15:55:00  32.082 -64.582  201.6  5000101706  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  93  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  93              None             None               None              None
#
#     oxygen_WOA_clim
#  93            None  ,
#                     time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  94  1991-05-02T15:55:00  32.082 -64.582  301.3  5000101705  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  94  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  94              None             None               None              None
#
#     oxygen_WOA_clim
#  94            None  ,
#                     time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  95  1991-05-02T15:55:00  32.082 -64.582  500.4  5000101704  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  95  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  95              None             None               None              None
#
#     oxygen_WOA_clim
#  95            None  ,
#                     time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  96  1991-05-02T15:55:00  32.082 -64.582  700.7  5000101703  NaN       NaN
#
#       chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  96  None  None  None  None  None  None  None             None
#
#     salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  96              None             None               None              None
#
#     oxygen_WOA_clim
#  96            None  ,
#                     time     lat     lon  depth   cruise_ID  TOC phosphate  \
# ...
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  968  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  968              None             None               None              None
#
#      oxygen_WOA_clim
#  968            None  ,
#                      time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  969  1992-09-30T11:40:00  31.838 -63.829  122.3  5000601606  NaN       NaN
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  969  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  969              None             None               None              None
#
#      oxygen_WOA_clim
#  969            None  ,
#                      time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  970  1992-09-30T11:40:00  31.838 -63.829  152.7  5000601605  NaN       NaN
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  970  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  970              None             None               None              None
#
#      oxygen_WOA_clim
#  970            None  ,
#                      time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  971  1992-09-30T11:40:00  31.838 -63.829  200.3  5000601604  NaN       NaN
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  971  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  971              None             None               None              None
#
#      oxygen_WOA_clim
#  971            None  ,
#                      time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  972  1992-09-30T11:40:00  31.838 -63.829  300.2  5000601603  NaN       NaN
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  972  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  972              None             None               None              None
#
#      oxygen_WOA_clim
#  972            None  ,
#                      time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  973  1992-09-30T11:40:00  31.838 -63.829  398.7  5000601602  NaN       NaN
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  973  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  973              None             None               None              None
#
#      oxygen_WOA_clim
#  973            None  ,
#                      time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  974  1992-09-30T11:40:00  31.838 -63.829  500.1  5000601601  NaN       NaN
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  974  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  974              None             None               None              None
#
#      oxygen_WOA_clim
#  974            None  ,
#                      time    lat     lon depth   cruise_ID  TOC phosphate  \
#  975  1992-09-30T14:28:00  31.84 -63.497   0.8  5000601710  NaN       NaN
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  975  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  975              None             None               None              None
#
#      oxygen_WOA_clim
#  975            None  ,
#                      time    lat     lon depth   cruise_ID  TOC phosphate  \
#  976  1992-09-30T14:28:00  31.84 -63.497  23.2  5000601709  NaN       NaN
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  976  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  976              None             None               None              None
#
#      oxygen_WOA_clim
#  976            None  ,
#                      time    lat     lon depth   cruise_ID  TOC phosphate  \
#  977  1992-09-30T14:28:00  31.84 -63.497  49.2  5000601708  NaN       NaN
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  977  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  977              None             None               None              None
#
#      oxygen_WOA_clim
#  977            None  ,
#                      time    lat     lon depth   cruise_ID  TOC phosphate  \
#  978  1992-09-30T14:28:00  31.84 -63.497  74.2  5000601707  NaN       NaN
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  978  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  978              None             None               None              None
#
#      oxygen_WOA_clim
#  978            None  ,
#                      time    lat     lon depth   cruise_ID  TOC phosphate  \
#  979  1992-09-30T14:28:00  31.84 -63.497  99.5  5000601706  NaN       NaN
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  979  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  979              None             None               None              None
#
#      oxygen_WOA_clim
#  979            None  ,
#                      time    lat     lon  depth   cruise_ID  TOC phosphate  \
#  980  1992-09-30T14:28:00  31.84 -63.497  124.4  5000601705  NaN       NaN
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  980  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  980              None             None               None              None
#
#      oxygen_WOA_clim
#  980            None  ,
#                      time    lat     lon  depth   cruise_ID  TOC phosphate  \
#  981  1992-09-30T14:28:00  31.84 -63.497  149.6  5000601704  NaN       NaN
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  981  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  981              None             None               None              None
#
#      oxygen_WOA_clim
#  981            None  ,
#                      time    lat     lon  depth   cruise_ID  TOC phosphate  \
#  982  1992-09-30T14:28:00  31.84 -63.497  199.1  5000601703  NaN       NaN
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  982  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  982              None             None               None              None
#
#      oxygen_WOA_clim
#  982            None  ,
#                      time    lat     lon  depth   cruise_ID  TOC phosphate  \
#  983  1992-09-30T14:28:00  31.84 -63.497  300.1  5000601702  NaN       NaN
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  983  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  983              None             None               None              None
#
#      oxygen_WOA_clim
#  983            None  ,
#                      time    lat     lon  depth   cruise_ID  TOC phosphate  \
#  984  1992-09-30T14:28:00  31.84 -63.497  400.8  5000601701  NaN       NaN
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  984  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  984              None             None               None              None
#
#      oxygen_WOA_clim
#  984            None  ,
#                      time     lat     lon depth   cruise_ID  TOC phosphate  \
#  985  1992-09-30T17:20:00  31.837 -63.166   2.5  5000601811  NaN       NaN
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  985  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  985              None             None               None              None
#
#      oxygen_WOA_clim
#  985            None  ,
#                      time     lat     lon depth   cruise_ID  TOC phosphate  \
#  986  1992-09-30T17:20:00  31.837 -63.166  25.3  5000601810  NaN       NaN
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  986  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  986              None             None               None              None
#
#      oxygen_WOA_clim
#  986            None  ,
#                      time     lat     lon depth   cruise_ID  TOC phosphate  \
#  987  1992-09-30T17:20:00  31.837 -63.166  49.2  5000601809  NaN       NaN
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  987  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  987              None             None               None              None
#
#      oxygen_WOA_clim
#  987            None  ,
#                      time     lat     lon depth   cruise_ID  TOC phosphate  \
#  988  1992-09-30T17:20:00  31.837 -63.166  75.7  5000601808  NaN       NaN
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  988  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  988              None             None               None              None
#
#      oxygen_WOA_clim
#  988            None  ,
#                      time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  989  1992-09-30T17:20:00  31.837 -63.166  100.2  5000601807  NaN       NaN
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  989  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  989              None             None               None              None
#
#      oxygen_WOA_clim
#  989            None  ,
#                      time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  990  1992-09-30T17:20:00  31.837 -63.166  124.9  5000601806  NaN       NaN
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  990  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  990              None             None               None              None
#
#      oxygen_WOA_clim
#  990            None  ,
#                      time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  991  1992-09-30T17:20:00  31.837 -63.166  150.7  5000601805  NaN       NaN
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  991  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  991              None             None               None              None
#
#      oxygen_WOA_clim
#  991            None  ,
#                      time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  992  1992-09-30T17:20:00  31.837 -63.166  200.6  5000601804  NaN       NaN
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  992  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  992              None             None               None              None
#
#      oxygen_WOA_clim
#  992            None  ,
#                      time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  993  1992-09-30T17:20:00  31.837 -63.166  300.3  5000601803  NaN       NaN
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  993  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  993              None             None               None              None
#
#      oxygen_WOA_clim
#  993            None  ,
#                      time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  994  1992-09-30T17:20:00  31.837 -63.166  399.6  5000601802  NaN       NaN
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  994  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  994              None             None               None              None
#
#      oxygen_WOA_clim
#  994            None  ,
#                      time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  995  1992-09-30T17:20:00  31.837 -63.166  501.0  5000601801  NaN       NaN
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  995  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  995              None             None               None              None
#
#      oxygen_WOA_clim
#  995            None  ,
#                      time     lat     lon depth   cruise_ID  TOC phosphate  \
#  996  1992-09-30T20:20:00  32.175 -63.163   2.1  5000601912  NaN       NaN
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  996  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  996              None             None               None              None
#
#      oxygen_WOA_clim
#  996            None  ,
#                      time     lat     lon depth   cruise_ID  TOC phosphate  \
#  997  1992-09-30T20:20:00  32.175 -63.163  10.7  5000601911  NaN       NaN
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  997  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  997              None             None               None              None
#
#      oxygen_WOA_clim
#  997            None  ,
#                      time     lat     lon depth   cruise_ID  TOC phosphate  \
#  998  1992-09-30T20:20:00  32.175 -63.163  23.3  5000601910  NaN       NaN
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  998  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  998              None             None               None              None
#
#      oxygen_WOA_clim
#  998            None  ,
#                      time     lat     lon depth   cruise_ID  TOC phosphate  \
#  999  1992-09-30T20:20:00  32.175 -63.163  48.9  5000601909  NaN       NaN
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  999  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  999              None             None               None              None
#
#      oxygen_WOA_clim
#  999            None  ,
#  ...]

# %%
api = pycmap.API(token=API_KEY)


match(df.iloc[1], api, envs, cyanoFile, rowCount)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_12680\3276674149.py:1
# ----> 1 match(df, api, envs, cyanoFile, rowCount)
#
# NameError: name 'rowCount' is not defined

# %%
df.size
# Out:
# 298780

# %%
df.iloc[1]
# Out:
# time                  1991-04-29T14:30:00
# lat                                32.165
# lon                               -64.503
# depth                                24.2
# cruise_ID                      5000100111
# TOC                                   NaN
# phosphate                             NaN
# chl                                  None
# NO3                                  None
# PO4                                  None
# Fe                                   None
# O2                                   None
# Si                                   None
# PP                                   None
# density_WOA_clim                     None
# salinity_WOA_clim                    None
# nitrate_WOA_clim                     None
# phosphate_WOA_clim                   None
# silicate_WOA_clim                    None
# oxygen_WOA_clim                      None
# Name: 1, dtype: object

# %%
df.iloc[0]
# Out:
# time                  1991-04-29T14:30:00
# lat                                32.165
# lon                               -64.503
# depth                                 2.4
# cruise_ID                      5000100112
# TOC                                   NaN
# phosphate                             NaN
# chl                              0.135655
# NO3                              1.939887
# PO4                              0.158448
# Fe                               0.000035
# O2                             234.741243
# Si                               2.917146
# PP                               0.023538
# density_WOA_clim                26.057992
# salinity_WOA_clim               36.622066
# nitrate_WOA_clim                  0.10174
# phosphate_WOA_clim               0.016469
# silicate_WOA_clim                0.644847
# oxygen_WOA_clim                  5.308658
# Name: 0, dtype: object

# %%
len(dfs)
# Out:
# 14939

# %%
df.size
# Out:
# 298780

# %%
    for cyanoFile in cyanoFiles:
        df = pd.read_csv(cyanoFile)
        df = add_env_columns(df, envs)
        dfs = [df.loc[i].to_frame().T for i in range(len(df))]
        colocalizedDF  = pd.DataFrame({})
        with concurrent.futures.ThreadPoolExecutor() as executor:
            futureObjs = executor.map(match, dfs, [api] * len(dfs), [envs] * len(dfs), [cyanoFile] * len(dfs), [len(dfs)] * len(dfs))
            for fo in futureObjs:
                if len(colocalizedDF) < 1: #e.g., this is the first file
                    colocalizedDF = fo
                else: #any subsequent files are concatenated
                    colocalizedDF = pd.concat([colocalizedDF, fo], ignore_index=True)  
        saveColocalizedCSV(colocalizedDF)

# %%
len(colocalizedDF)
# Out:
# 0

# %%
one = match(df,api,envs,cyanoFile,len(df))
# Out:
# Invalid dataframe input.
# Expected a single row dataframe but received 14939 rows.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# C:\Users\klongnecker\AppData\Local\miniconda3\Lib\site-packages\IPython\core\interactiveshell.py:3680: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
idx = 1

# %%
one = match(df[idx],api,envs,cyanoFile,len(df))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\miniconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 one = match(df[idx],api,envs,cyanoFile,len(df))
#
# File ~\AppData\Local\miniconda3\Lib\site-packages\pandas\core\frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File ~\AppData\Local\miniconda3\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 1

# %%
envs.size
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 envs.size
#
# AttributeError: 'dict' object has no attribute 'size'

# %%
pip install debugger
# Out:
# Requirement already satisfied: debugger in c:\users\klongnecker\appdata\local\miniconda3\lib\site-packages (1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
#used this to step into the function and debug it, also need line with Tracer()() 
# from IPython.core.debugger import Tracer 
from IPython.core.debugger import Tracer
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[32], line 3
#       1 #used this to step into the function and debug it, also need line with Tracer()()
#       2 # from IPython.core.debugger import Tracer
# ----> 3 from IPython.core.debugger import Tracer
#
# ImportError: cannot import name 'Tracer' from 'IPython.core.debugger' (C:\Users\klongnecker\AppData\Local\miniconda3\Lib\site-packages\IPython\core\debugger.py)

# %%
for cyanoFile in cyanoFiles:
    df = pd.read_csv(cyanoFile)
    df = add_env_columns(df, envs)
    dfs = [df.loc[i].to_frame().T for i in range(len(df))]
    colocalizedDF  = pd.DataFrame({})
    with concurrent.futures.ThreadPoolExecutor() as executor:
        futureObjs = executor.map(match, dfs, [api] * len(dfs), [envs] * len(dfs), [cyanoFile] * len(dfs), [len(dfs)] * len(dfs))
        embed()
        for fo in futureObjs:
            if len(colocalizedDF) < 1: #e.g., this is the first file
                colocalizedDF = fo
            else: #any subsequent files are concatenated
                colocalizedDF = pd.concat([colocalizedDF, fo], ignore_index=True)  
    saveColocalizedCSV(colocalizedDF)
# Out:
# Python 3.13.2 | packaged by Anaconda, Inc. | (main, Feb  6 2025, 18:49:14) [MSC v.1929 64 bit (AMD64)]
# Type 'copyright', 'credits' or 'license' for more information
# IPython 9.3.0 -- An enhanced Interactive Python. Type '?' for help.
# Tip: You can use `%hist` to view history, see the options with `%history?`
# In [1]:  match
# Out[1]: <function __main__.match(df, api, envs, cyanoFile, rowCount)>
# In [2]:  dfs
# Out[2]:
# [                  time     lat     lon depth   cruise_ID  TOC phosphate  \
#  0  1988-10-21T04:55:00  31.833 -64.167   1.0  1000108112  NaN       0.0
#
#          chl       NO3       PO4        Fe          O2        Si        PP  \
#  0  0.075749  0.007559  0.023802  0.000213  213.651904  2.568182  0.002471
#
#    density_WOA_clim salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim  \
#  0         24.23414         36.458775          0.05295           0.011797
#
#    silicate_WOA_clim oxygen_WOA_clim
#  0          0.854648        4.743575  ,
#                    time     lat     lon depth   cruise_ID  TOC phosphate  \
#  0  1988-10-21T04:55:00  31.833 -64.167  10.0  1000108111  NaN       0.0
#
#          chl       NO3       PO4        Fe          O2        Si        PP  \
#  0  0.075749  0.008065  0.023859  0.000212  213.828594  2.568457  0.002281
#
#    density_WOA_clim salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim  \
#  0        24.272935         36.464915         0.076731           0.008645
#
#    silicate_WOA_clim oxygen_WOA_clim
#  0           0.86555        4.755136  ,
#                    time     lat     lon depth   cruise_ID  TOC phosphate  \
#  0  1988-10-21T04:55:00  31.833 -64.167  25.0  1000108110  NaN       0.0
#
#          chl       NO3       PO4        Fe          O2        Si        PP  \
#  0  0.075749  0.014135  0.024554  0.000204  215.280027  2.571846  0.002067
#
#    density_WOA_clim salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim  \
#  0        24.398674         36.478948         0.036246           0.008788
#
#    silicate_WOA_clim oxygen_WOA_clim
#  0          0.901897        4.748691  ,
#                    time     lat     lon depth   cruise_ID  TOC phosphate  \
#  0  1988-10-21T04:55:00  31.833 -64.167  50.0  1000108109  NaN       0.0
#
#          chl      NO3       PO4        Fe          O2        Si        PP  \
#  0  0.075749  0.40705  0.054994  0.000123  225.856963  2.676139  0.005371
#
#    density_WOA_clim salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim  \
#  0        24.896365         36.546905         0.038377           0.011136
#
#    silicate_WOA_clim oxygen_WOA_clim
#  0          0.782986        4.980268  ,
#                    time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  0  1988-10-21T04:55:00  31.833 -64.167  100.0  1000108108  NaN      0.04
#
#          chl  NO3  PO4   Fe   O2   Si   PP density_WOA_clim salinity_WOA_clim  \
#  0  0.075749  NaN  NaN  NaN  NaN  NaN  NaN        26.303049         36.623137
#
#    nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim oxygen_WOA_clim
#  0         0.888239           0.054669          0.874968        4.883524  ,
#                    time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  0  1988-10-21T04:55:00  31.833 -64.167  150.0  1000108107  NaN       0.0
#
#          chl  NO3  PO4   Fe   O2   Si   PP density_WOA_clim salinity_WOA_clim  \
#  0  0.075749  NaN  NaN  NaN  NaN  NaN  NaN        26.885038          36.57995
#
#    nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim oxygen_WOA_clim
#  0         1.951071           0.086041          1.017028        4.804834  ,
#                    time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  0  1988-10-21T04:55:00  31.833 -64.167  200.0  1000108106  NaN      0.05
#
#          chl  NO3  PO4   Fe   O2   Si   PP density_WOA_clim salinity_WOA_clim  \
#  0  0.075749  NaN  NaN  NaN  NaN  NaN  NaN        27.207715           36.5498
#
#    nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim oxygen_WOA_clim
#  0         2.561606           0.141164           1.26418        4.766405  ,
#                    time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  0  1988-10-21T04:55:00  31.833 -64.167  225.0  1000108105  NaN       0.0
#
#          chl       NO3       PO4       Fe          O2        Si        PP  \
#  0  0.075749  9.504113  0.628847  0.00045  192.797389  5.825905  0.000002
#
#    density_WOA_clim salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim  \
#  0        27.349527         36.542452         2.734726           0.150509
#
#    silicate_WOA_clim oxygen_WOA_clim
#  0          1.280775        4.787804  ,
#                    time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  0  1988-10-21T04:55:00  31.833 -64.167  250.0  1000108104  NaN      0.06
#
#          chl  NO3  PO4   Fe   O2   Si   PP density_WOA_clim salinity_WOA_clim  \
#  0  0.075749  NaN  NaN  NaN  NaN  NaN  NaN        27.480771         36.533166
#
#    nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim oxygen_WOA_clim
#  0         2.862839           0.134654          1.447107        4.783761  ,
#                    time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  0  1988-10-21T04:55:00  31.833 -64.167  300.0  1000108103  NaN      0.07
#
#          chl  NO3  PO4   Fe   O2   Si   PP density_WOA_clim salinity_WOA_clim  \
#  0  0.075749  NaN  NaN  NaN  NaN  NaN  NaN        27.741733         36.515352
#
#    nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim oxygen_WOA_clim
#  0         3.304189           0.137811          1.557783        4.711707  ,
#                    time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  0  1988-10-21T04:55:00  31.833 -64.167  400.0  1000108102  NaN      0.19
#
#          chl  NO3  PO4   Fe   O2   Si   PP density_WOA_clim salinity_WOA_clim  \
#  0  0.075749  NaN  NaN  NaN  NaN  NaN  Na
,
#                    time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  0  1988-12-19T17:30:00  31.675 -63.972  107.0  1000300607  NaN       NaN
#
#          chl       NO3       PO4        Fe         O2        Si        PP  \
#  0  0.130055  4.815195  0.347027  0.000179  209.26554  3.899611  0.000106
#
#    density_WOA_clim salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim  \
#  0              NaN               NaN              NaN                NaN
#
#    silicate_WOA_clim oxygen_WOA_clim
#  0               NaN             NaN  ,
#                    time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  0  1988-12-19T17:30:00  31.675 -63.972  131.9  1000300606  NaN      0.03
#
#          chl       NO3      PO4        Fe          O2        Si        PP  \
#  0  0.130055  6.664334  0.45907  0.000254  201.927927  4.524607  0.000037
#
#    density_WOA_clim salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim  \
#  0              NaN               NaN              NaN                NaN
#
#    silicate_WOA_clim oxygen_WOA_clim
#  0               NaN             NaN  ,
#                    time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  0  1988-12-19T17:30:00  31.675 -63.972  157.2  1000300605  NaN       NaN
#
#          chl       NO3       PO4        Fe          O2        Si        PP  \
#  0  0.130055  7.948069  0.535509  0.000328  196.704409  5.036898  0.000012
#
#    density_WOA_clim salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim  \
#  0              NaN               NaN              NaN                NaN
#
#    silicate_WOA_clim oxygen_WOA_clim
#  0               NaN             NaN  ,
#                    time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  0  1988-12-19T17:30:00  31.675 -63.972  181.1  1000300604  NaN       NaN
#
#          chl  NO3  PO4   Fe   O2   Si   PP density_WOA_clim salinity_WOA_clim  \
#  0  0.130055  NaN  NaN  NaN  NaN  NaN  NaN              NaN               NaN
#
#    nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim oxygen_WOA_clim
#  0              NaN                NaN               NaN             NaN  ,
#                    time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  0  1988-12-19T17:30:00  31.675 -63.972  207.0  1000300603  NaN       NaN
#
#          chl  NO3  PO4   Fe   O2   Si   PP density_WOA_clim salinity_WOA_clim  \
#  0  0.130055  NaN  NaN  NaN  NaN  NaN  NaN              NaN               NaN
#
#    nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim oxygen_WOA_clim
#  0              NaN                NaN               NaN             NaN  ,
#                    time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  0  1988-12-19T17:30:00  31.675 -63.972  230.8  1000300602  NaN       NaN
#
#          chl  NO3  PO4   Fe   O2   Si   PP density_WOA_clim salinity_WOA_clim  \
#  0  0.130055  NaN  NaN  NaN  NaN  NaN  NaN              NaN               NaN
#
#    nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim oxygen_WOA_clim
#  0              NaN                NaN               NaN             NaN  ,
#                    time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  0  1988-12-19T17:30:00  31.675 -63.972  261.0  1000300601  NaN       NaN
#
#          chl  NO3  PO4   Fe   O2   Si   PP density_WOA_clim salinity_WOA_clim  \
#  0  0.130055  NaN  NaN  NaN  NaN  NaN  NaN              NaN               NaN
#
#    nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim oxygen_WOA_clim
#  0              NaN                NaN               NaN             NaN  ,
#                    time     lat     lon depth   cruise_ID  TOC phosphate  \
#  0  1989-01-26T08:20:00  31.655 -64.207   4.8  1000400110  NaN       0.0
#
#        chl      NO3       PO4        Fe          O2        Si        PP  \
#  0  0.1475  1.92336  0.160369  0.000051  226.001316  2.944828  0.023261
#
#    density_WOA_clim salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim  \
#  0        25.811146         36.626744         0.259568           0.046695
#
#    silicate_WOA_clim oxygen_WOA_clim
#  0          0.867617        5.135372  ,
#                    time     lat     lon depth   cruise_ID  TOC phosphate  \
#  0  1989-01-26T08:20:00  31.655 -64.207  16.3  1000400109  NaN       0.0
#
#        chl       NO3       PO4        Fe          O2        Si        PP  \
#  0  0.1475  1.936004  0.161835  0.000052  225.703302  2.948195  0.015761
#
#    density_WOA_clim salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim  \
#  0        25.891901         36.620494         0.203981           0.047789
#
#    silicate_WOA_clim oxygen_WOA_clim
#  0          0.898916        5.074875  ,
#                    time     lat     lon depth   cruise_ID  TOC phosphate  \
#  0  1989-01-26T08:20:00  31.655 -64.207  35.1  1000400108  NaN      0.04
#
#        chl       NO3       PO4        Fe          O2        Si       PP  \
#  0  0.1475  1.980196  0.166766  0.000053  224.885441  2.960962  0.00542
#
#    density_WOA_clim salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim  \
#  0        25.997429         36.618051         0.205225           0.048185
#
#    silicate_WOA_clim oxygen_WOA_clim
#  0          0.926123        5.072486  ,
#                    time     lat     lon depth   cruise_ID  TOC phosphate  \
#  0  1989-01-26T08:20:00  31.655 -64.207  49.5  1000400107  NaN       0.0
#
#        chl       NO3       PO4        Fe          O2       Si        PP  \
#  0  0.1475  2.017332  0.170567  0.000055  224.281007  2.97223  0.002521
#
#    density_WOA_clim salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim  \
#  0        26.049692           36.6184         0.212661           0.048977
#
#    silicate_WOA_clim oxygen_WOA_clim
#  0          0.948549         5.08226  ,
#                    time     lat     lon depth   cruise_ID  TOC phosphate  \
#  0  1989-01-26T08:20:00  31.655 -64.207  63.5  1000408102  NaN       0.0
#
#        chl       NO3       PO4        Fe          O2        Si        PP  \
#  0  0.1475  2.106506  0.178313  0.000059  223.183454  2.999011  0.000866
#
#    density_WOA_clim salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim  \
#  0        26.125424         36.618122         0.263281           0.050703
#
#    silicate_WOA_clim oxygen_WOA_clim
#  0          0.930027        5.068647  ,
#                    time     lat     lon depth   cruise_ID  TOC phosphate  \
#  0  1989-01-26T08:20:00  31.655 -64.207  76.4  1000400106  NaN      0.05
#
#        chl       NO3       PO4        Fe         O2        Si        PP  \
#  0  0.1475  2.209036  0.186051  0.000063  222.19547  3.029329  0.000443
#
#    density_WOA_clim salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim  \
#  0        26.201775         36.612475         0.315654           0.050153
#
#    silicate_WOA_clim oxygen_WOA_clim
#  0          0.904794        5.048503  ,
#                    time     lat     lon depth   cruise_ID  TOC phosphate  \
#  0  1989-01-26T08:20:00  31.655 -64.207  94.6  1000400105  NaN      0.04
#
#        chl       NO3       PO4        Fe          O2       Si        PP  \
#  0  0.1475  2.529981  0.207151  0.000074  220.600282  3.12053  0.000212
#
#    density_WOA_clim salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim  \
#  0          26.2818         36.609359         0.351652           0.055983
#
#    silicate_WOA_clim oxygen_WOA_clim
#  0           0.91238        5.056106  ,
#                    time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  0  1989-01-26T08:20:00  31.655 -64.207  125.1  1000400104  NaN      0.04
#
#        chl  NO3  PO4   Fe   O2   Si   PP density_WOA_clim salinity_WOA_clim  \
#  0  0.1475  NaN  NaN  NaN  NaN  NaN  NaN        26.552268           36.6038
#
#    nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim oxygen_WOA_clim
#  0         0.934089           0.060008          0.953723        4.938505  ,
#                    time     lat     lon  depth   cruise_ID  TOC phosphate  \
# ...
#
#      oxygen_WOA_clim
#  970            None  ,
#                      time     lat     lon depth   cruise_ID  TOC phosphate  \
#  971  1991-02-11T16:40:00  31.746 -64.147  70.1  1002900107  NaN       0.0
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  971  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  971              None             None               None              None
#
#      oxygen_WOA_clim
#  971            None  ,
#                      time     lat     lon depth   cruise_ID  TOC phosphate  \
#  972  1991-02-11T16:40:00  31.746 -64.147  99.6  1002900106  NaN       0.0
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  972  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  972              None             None               None              None
#
#      oxygen_WOA_clim
#  972            None  ,
#                      time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  973  1991-02-11T16:40:00  31.746 -64.147  122.0  1002900105  NaN       0.0
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  973  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  973              None             None               None              None
#
#      oxygen_WOA_clim
#  973            None  ,
#                      time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  974  1991-02-11T16:40:00  31.746 -64.147  148.9  1002900104  NaN       0.0
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  974  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  974              None             None               None              None
#
#      oxygen_WOA_clim
#  974            None  ,
#                      time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  975  1991-02-11T16:40:00  31.746 -64.147  184.7  1002900103  NaN       0.0
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  975  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  975              None             None               None              None
#
#      oxygen_WOA_clim
#  975            None  ,
#                      time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  976  1991-02-11T16:40:00  31.746 -64.147  199.2  1002900102  NaN       0.0
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  976  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  976              None             None               None              None
#
#      oxygen_WOA_clim
#  976            None  ,
#                      time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  977  1991-02-11T16:40:00  31.746 -64.147  248.9  1002900101  NaN      0.09
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  977  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  977              None             None               None              None
#
#      oxygen_WOA_clim
#  977            None  ,
#                      time     lat    lon depth   cruise_ID  TOC phosphate  \
#  978  1991-02-20T15:25:00  31.792 -64.16   1.4  2002900312  NaN       0.0
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  978  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  978              None             None               None              None
#
#      oxygen_WOA_clim
#  978            None  ,
#                      time     lat    lon depth   cruise_ID  TOC phosphate  \
#  979  1991-02-20T15:25:00  31.792 -64.16   9.5  2002900311  NaN       0.0
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  979  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  979              None             None               None              None
#
#      oxygen_WOA_clim
#  979            None  ,
#                      time     lat    lon depth   cruise_ID  TOC phosphate  \
#  980  1991-02-20T15:25:00  31.792 -64.16  18.5  2002900310  NaN       0.0
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  980  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  980              None             None               None              None
#
#      oxygen_WOA_clim
#  980            None  ,
#                      time     lat    lon depth   cruise_ID  TOC phosphate  \
#  981  1991-02-20T15:25:00  31.792 -64.16  39.4  2002900309  NaN       0.0
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  981  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  981              None             None               None              None
#
#      oxygen_WOA_clim
#  981            None  ,
#                      time     lat    lon depth   cruise_ID  TOC phosphate  \
#  982  1991-02-20T15:25:00  31.792 -64.16  91.6  2002900308  NaN       0.0
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  982  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  982              None             None               None              None
#
#      oxygen_WOA_clim
#  982            None  ,
#                      time     lat    lon depth   cruise_ID  TOC phosphate  \
#  983  1991-02-20T15:25:00  31.792 -64.16  99.2  2002900307  NaN       0.0
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  983  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  983              None             None               None              None
#
#      oxygen_WOA_clim
#  983            None  ,
#                      time     lat    lon  depth   cruise_ID  TOC phosphate  \
#  984  1991-02-20T15:25:00  31.792 -64.16  110.6  2002900306  NaN       0.0
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  984  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  984              None             None               None              None
#
#      oxygen_WOA_clim
#  984            None  ,
#                      time     lat    lon  depth   cruise_ID  TOC phosphate  \
#  985  1991-02-20T15:25:00  31.792 -64.16  139.7  2002900305  NaN       0.0
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  985  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  985              None             None               None              None
#
#      oxygen_WOA_clim
#  985            None  ,
#                      time     lat    lon  depth   cruise_ID  TOC phosphate  \
#  986  1991-02-20T15:25:00  31.792 -64.16  149.3  2002900304  NaN       0.0
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  986  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  986              None             None               None              None
#
#      oxygen_WOA_clim
#  986            None  ,
#                      time     lat    lon  depth   cruise_ID  TOC phosphate  \
#  987  1991-02-20T15:25:00  31.792 -64.16  171.9  2002900303  NaN       0.0
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  987  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  987              None             None               None              None
#
#      oxygen_WOA_clim
#  987            None  ,
#                      time     lat    lon  depth   cruise_ID  TOC phosphate  \
#  988  1991-02-20T15:25:00  31.792 -64.16  200.8  2002900302  NaN       0.0
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  988  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  988              None             None               None              None
#
#      oxygen_WOA_clim
#  988            None  ,
#                      time     lat    lon  depth   cruise_ID  TOC phosphate  \
#  989  1991-02-20T15:25:00  31.792 -64.16  252.2  2002900301  NaN      0.07
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  989  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  989              None             None               None              None
#
#      oxygen_WOA_clim
#  989            None  ,
#                      time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  990  1991-03-13T23:45:00  31.755 -64.168  300.4  1003000112  NaN       NaN
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  990  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  990              None             None               None              None
#
#      oxygen_WOA_clim
#  990            None  ,
#                      time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  991  1991-03-13T23:45:00  31.755 -64.168  399.1  1003000111  NaN      0.19
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  991  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  991              None             None               None              None
#
#      oxygen_WOA_clim
#  991            None  ,
#                      time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  992  1991-03-13T23:45:00  31.755 -64.168  499.1  1003000110  NaN      0.43
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  992  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  992              None             None               None              None
#
#      oxygen_WOA_clim
#  992            None  ,
#                      time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  993  1991-03-13T23:45:00  31.755 -64.168  598.4  1003000109  NaN       0.8
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  993  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  993              None             None               None              None
#
#      oxygen_WOA_clim
#  993            None  ,
#                      time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  994  1991-03-13T23:45:00  31.755 -64.168  700.7  1003000108  NaN      1.23
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  994  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  994              None             None               None              None
#
#      oxygen_WOA_clim
#  994            None  ,
#                      time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  995  1991-03-13T23:45:00  31.755 -64.168  798.8  1003000107  NaN      1.49
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  995  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  995              None             None               None              None
#
#      oxygen_WOA_clim
#  995            None  ,
#                      time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  996  1991-03-13T23:45:00  31.755 -64.168  899.4  1003000106  NaN      1.67
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  996  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  996              None             None               None              None
#
#      oxygen_WOA_clim
#  996            None  ,
#                      time     lat     lon  depth   cruise_ID  TOC phosphate  \
#  997  1991-03-13T23:45:00  31.755 -64.168  998.7  1003000105  NaN      1.57
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  997  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  997              None             None               None              None
#
#      oxygen_WOA_clim
#  997            None  ,
#                      time     lat     lon depth   cruise_ID  TOC phosphate  \
#  998  1991-03-14T12:10:00  31.807 -64.241   1.0  1003000208  NaN       NaN
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  998  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  998              None             None               None              None
#
#      oxygen_WOA_clim
#  998            None  ,
#                      time     lat     lon depth   cruise_ID  TOC phosphate  \
#  999  1991-03-14T12:10:00  31.807 -64.241  20.0  1003000207  NaN       NaN
#
#        chl   NO3   PO4    Fe    O2    Si    PP density_WOA_clim  \
#  999  None  None  None  None  None  None  None             None
#
#      salinity_WOA_clim nitrate_WOA_clim phosphate_WOA_clim silicate_WOA_clim  \
#  999              None             None               None              None
#
#      oxygen_WOA_clim
#  999            None  ,
#  ...]
# In [3]:  dfs.size
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 dfs.size
#
# AttributeError: 'list' object has no attribute 'size'
# In [4]:  dfs.len
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 dfs.len
#
# AttributeError: 'list' object has no attribute 'len'
# In [5]:  len(dfs)
# Out[5]: 58989
# In [6]:  cyanoFile.head
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 cyanoFile.head
#
# AttributeError: 'str' object has no attribute 'head'
# In [7]:  cyanoFile
# Out[7]: './data\\tblBATS_Bottle.csv'
# In [8]:  futureObjs
# Out[8]: <generator object Executor.map.<locals>.result_iterator at 0x0000022A10D16110>
# In [9]:  futureObjs.size
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 futureObjs.size
#
# AttributeError: 'generator' object has no attribute 'size'
# In [10]:  exit

# %%
 raise SystemExit("Stop execution here")

# %% [markdown]
# #Stick some code below this spot as a holding zone

# %%
#this was helpful to dig around when I was trying to find the error in the cyano_ML code

def _atomic_match(
                 spName, sourceTable, sourceVar, targetTable, targetVar, 
                 dt1, dt2, lat1, lat2, lon1, lon2, depth1, depth2, 
                 temporalTolerance, latTolerance, lonTolerance, depthTolerance
                 ):

    """
    Colocalizes the source variable (from source table) with a single target variable (from target table).
    The tolerance parameters set the matching boundaries between the source and target data sets. 
    Returns a dataframe containing the source variable joined with the target variable.
    """

    args = [spName, sourceTable, sourceVar, targetTable, targetVar, 
            dt1, dt2, lat1, lat2, lon1, lon2, depth1, depth2, 
            temporalTolerance, latTolerance, lonTolerance, depthTolerance]
    args = [str(arg) for arg in args]        
    query = "EXEC %s '%s', '%s','%s', '%s', '%s', '%s', '%s', '%s', '%s', '%s', '%s', '%s', '%s', '%s', '%s', '%s'" % tuple(args)
    return API().query(query)

# %%
len(args) #args is a list
