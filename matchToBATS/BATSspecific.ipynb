# %% [markdown]
# Move on to doing BATS, leave Prochlorococcus example here but it required the HPC to run\
# Krista Longnecker, 18 June 2025

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pycmap
from pycmap.viz import plot_timeseries

# %%
#this is convoluted, but works since config.py is up one directory from where I am working
import os #sometimes useful
os.chdir("../config")
from config import API_KEY
os.chdir("../matchToBATS")
#get the API from the CMAP website scripts have the API in config/config.py
#api = pycmap.API(token=<put API key here>, vizEngine='plotly')

# %%
# %run collect.py
# Out:
# Downloading  ('tblBATS_Bottle', ['cruise_ID', 'TOC', 'phosphate'])  ...
# Downloading  ('tblGLODAP', ['cruise_expocode', 'toc', 'phosphate'])  ...
# Downloading  ('tblBATS_Bottle_Validation', ['cruise_ID', 'TOC', 'phosphate'])  ...
# Downloading  ('tblGeotraces_Seawater_IDP2021v2', ['cruise_id', 'DOC_D_CONC_BOTTLE', 'PHOSPHATE_D_CONC_BOTTLE'])  ...

# %%
 raise SystemExit("Stop execution here")

# %%
# toc = api.search_catalog("toc") #this will match proTOCol ...which comes up several times
# toc = api.search_catalog("TOC") #is the search case sensitive?
toc = api.search_catalog("Total Organic Carbon") #is the search case sensitive?

# %%
toc['Keywords']

# %%
toc['Keywords'][29]

# %%
#scripts are from the Simons CMAP article (case study), linked from LOM paper

# %%
#need to run this command after any edits are made to common.py; otherwise the notebook just reads in whatever was read in first
#I am not entirely sure what is going on, but I gather I can import the py file and then reload it as needed
from importlib import reload
import common
reload(common)
# Out:
# <module 'common' from 'C:\\Users\\klongnecker\\Documents\\Dropbox\\GitHub\\BATSwithCMAP\\matchToBATS\\common.py'>

# %%
#first, need to figure out how to run .py scripts from jupyter notebook
#scripts are all in matchToBATS
# %run collect.py
# Out:
# ********************************
# Downloading  ('tblSeaFlow_v1_5', ['cruise', 'abundance_prochloro', 'abundance_synecho', 'abundance_picoeuk'])  ...
# ********************************
#
#
# ********************************
# Downloading  ('tblFlombaum', ['prochlorococcus_abundance_flombaum', 'synechococcus_abundance_flombaum'])  ...
# ********************************

# %%
# %run colocalize.py
# Out:
# 0 / 7717
# 	2025-06-16 11:07:21.922484: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 1 / 7717
# 	2025-06-16 11:07:21.926260: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2 / 7717
# 	2025-06-16 11:07:21.928888: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 3 / 7717
# 	2025-06-16 11:07:21.931927: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 4 / 7717
# 	2025-06-16 11:07:21.933714: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 5 / 7717
# 	2025-06-16 11:07:21.936532: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 6 / 7717
# 	2025-06-16 11:07:21.938179: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 7 / 7717
# 	2025-06-16 11:07:21.940317: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 8 / 7717
# 	2025-06-16 11:07:21.943313: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 9 / 7717
# 	2025-06-16 11:07:21.946273: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 10 / 7717
# 	2025-06-16 11:07:21.948727: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 11 / 7717
# 	2025-06-16 11:07:21.951116: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 6 / 7717
# 	2025-06-16 11:07:22.254160: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 5 / 7717
# 	2025-06-16 11:07:22.281491: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 1 / 7717
# 	2025-06-16 11:07:22.289610: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 8 / 7717
# 	2025-06-16 11:07:22.300932: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2 / 7717
# 	2025-06-16 11:07:22.313373: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 3 / 7717
# 	2025-06-16 11:07:22.327443: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 11 / 7717
# 	2025-06-16 11:07:22.352782: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 9 / 7717
# 	2025-06-16 11:07:22.378875: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 12 / 7717
# 	2025-06-16 11:07:22.452636: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 13 / 7717
# 	2025-06-16 11:07:22.476305: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 14 / 7717
# 	2025-06-16 11:07:22.489270: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 15 / 7717
# 	2025-06-16 11:07:22.501828: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 7 / 7717
# 	2025-06-16 11:07:22.519533: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 16 / 7717
# 	2025-06-16 11:07:22.534497: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 4 / 7717
# 	2025-06-16 11:07:22.536571: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 17 / 7717
# 	2025-06-16 11:07:22.542665: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 0 / 7717
# 	2025-06-16 11:07:22.551399: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 18 / 7717
# 	2025-06-16 11:07:22.576788: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 19 / 7717
# 	2025-06-16 11:07:22.606597: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 10 / 7717
# 	2025-06-16 11:07:22.641729: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 20 / 7717
# 	2025-06-16 11:07:22.706231: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 21 / 7717
# 	2025-06-16 11:07:22.737350: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 22 / 7717
# 	2025-06-16 11:07:22.742453: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 12 / 7717
# 	2025-06-16 11:07:22.749043: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 14 / 7717
# 	2025-06-16 11:07:22.754001: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 13 / 7717
# 	2025-06-16 11:07:22.773724: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 15 / 7717
# 	2025-06-16 11:07:22.791282: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 16 / 7717
# 	2025-06-16 11:07:22.809535: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 17 / 7717
# 	2025-06-16 11:07:22.831929: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 18 / 7717
# 	2025-06-16 11:07:22.835505: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 23 / 7717
# 	2025-06-16 11:07:22.871763: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 19 / 7717
# 	2025-06-16 11:07:22.897060: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 24 / 7717
# 	2025-06-16 11:07:22.959356: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 25 / 7717
# 	2025-06-16 11:07:22.974650: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 26 / 7717
# 	2025-06-16 11:07:22.978973: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 27 / 7717
# 	2025-06-16 11:07:23.014229: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 20 / 7717
# 	2025-06-16 11:07:23.015200: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 28 / 7717
# 	2025-06-16 11:07:23.016024: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 21 / 7717
# 	2025-06-16 11:07:23.023975: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 29 / 7717
# 	2025-06-16 11:07:23.032763: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 30 / 7717
# 	2025-06-16 11:07:23.037964: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 22 / 7717
# 	2025-06-16 11:07:23.040420: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 31 / 7717
# 	2025-06-16 11:07:23.094133: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 23 / 7717
# 	2025-06-16 11:07:23.152924: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 32 / 7717
# 	2025-06-16 11:07:23.228121: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 33 / 7717
# 	2025-06-16 11:07:23.237056: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 34 / 7717
# 	2025-06-16 11:07:23.249391: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 25 / 7717
# 	2025-06-16 11:07:23.260567: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 24 / 7717
# 	2025-06-16 11:07:23.269578: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 26 / 7717
# 	2025-06-16 11:07:23.274129: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 29 / 7717
# 	2025-06-16 11:07:23.303963: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 30 / 7717
# 	2025-06-16 11:07:23.308008: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 27 / 7717
# 	2025-06-16 11:07:23.313067: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 28 / 7717
# 	2025-06-16 11:07:23.317859: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 31 / 7717
# 	2025-06-16 11:07:23.342606: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 35 / 7717
# 	2025-06-16 11:07:23.345544: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 36 / 7717
# 	2025-06-16 11:07:23.468583: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 37 / 7717
# 	2025-06-16 11:07:23.480677: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 38 / 7717
# 	2025-06-16 11:07:23.488480: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 33 / 7717
# 	2025-06-16 11:07:23.495346: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 39 / 7717
# 	2025-06-16 11:07:23.518000: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 40 / 7717
# 	2025-06-16 11:07:23.530394: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 41 / 7717
# 	2025-06-16 11:07:23.534149: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 34 / 7717
# 	2025-06-16 11:07:23.536591: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 32 / 7717
# 	2025-06-16 11:07:23.541480: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 42 / 7717
# 	2025-06-16 11:07:23.543381: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 43 / 7717
# 	2025-06-16 11:07:23.553533: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 35 / 7717
# 	2025-06-16 11:07:23.617227: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 44 / 7717
# 	2025-06-16 11:07:23.700226: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 36 / 7717
# 	2025-06-16 11:07:23.714112: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 45 / 7717
# 	2025-06-16 11:07:23.746444: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 46 / 7717
# 	2025-06-16 11:07:23.749107: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 37 / 7717
# 	2025-06-16 11:07:23.774628: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 38 / 7717
# 	2025-06-16 11:07:23.776580: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 47 / 7717
# 	2025-06-16 11:07:23.805948: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 40 / 7717
# 	2025-06-16 11:07:23.810591: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 41 / 7717
# 	2025-06-16 11:07:23.819512: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 39 / 7717
# 	2025-06-16 11:07:23.830197: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 43 / 7717
# 	2025-06-16 11:07:23.839786: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 42 / 7717
# 	2025-06-16 11:07:23.845614: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 48 / 7717
# 	2025-06-16 11:07:23.930495: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 49 / 7717
# 	2025-06-16 11:07:23.982250: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 44 / 7717
# 	2025-06-16 11:07:23.986910: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 50 / 7717
# 	2025-06-16 11:07:23.988321: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 45 / 7717
# 	2025-06-16 11:07:24.014724: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 46 / 7717
# 	2025-06-16 11:07:24.024443: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 51 / 7717
# 	2025-06-16 11:07:24.055861: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 52 / 7717
# 	2025-06-16 11:07:24.057002: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 53 / 7717
# 	2025-06-16 11:07:24.059107: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 54 / 7717
# 	2025-06-16 11:07:24.074672: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 55 / 7717
# 	2025-06-16 11:07:24.092536: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 47 / 7717
# 	2025-06-16 11:07:24.153132: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 56 / 7717
# 	2025-06-16 11:07:24.180753: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 57 / 7717
# 	2025-06-16 11:07:24.211433: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 58 / 7717
# 	2025-06-16 11:07:24.212766: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 48 / 7717
# 	2025-06-16 11:07:24.217447: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 50 / 7717
# 	2025-06-16 11:07:24.237087: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 49 / 7717
# 	2025-06-16 11:07:24.254262: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 51 / 7717
# 	2025-06-16 11:07:24.299057: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 54 / 7717
# 	2025-06-16 11:07:24.333018: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 59 / 7717
# 	2025-06-16 11:07:24.335166: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 53 / 7717
# 	2025-06-16 11:07:24.346700: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 55 / 7717
# 	2025-06-16 11:07:24.374102: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 52 / 7717
# 	2025-06-16 11:07:24.388800: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 60 / 7717
# 	2025-06-16 11:07:24.397362: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 61 / 7717
# 	2025-06-16 11:07:24.411711: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 56 / 7717
# 	2025-06-16 11:07:24.450880: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 62 / 7717
# 	2025-06-16 11:07:24.456890: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 57 / 7717
# 	2025-06-16 11:07:24.473131: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 58 / 7717
# 	2025-06-16 11:07:24.483416: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 63 / 7717
# 	2025-06-16 11:07:24.496855: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 64 / 7717
# 	2025-06-16 11:07:24.531719: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 65 / 7717
# 	2025-06-16 11:07:24.542071: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 66 / 7717
# 	2025-06-16 11:07:24.562340: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 67 / 7717
# 	2025-06-16 11:07:24.572412: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 59 / 7717
# 	2025-06-16 11:07:24.615814: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 68 / 7717
# 	2025-06-16 11:07:24.637714: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 60 / 7717
# 	2025-06-16 11:07:24.657670: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 69 / 7717
# 	2025-06-16 11:07:24.662850: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 70 / 7717
# 	2025-06-16 11:07:24.672791: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 61 / 7717
# 	2025-06-16 11:07:24.710149: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 62 / 7717
# 	2025-06-16 11:07:24.717772: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 63 / 7717
# 	2025-06-16 11:07:24.793163: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 71 / 7717
# 	2025-06-16 11:07:24.809608: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 64 / 7717
# 	2025-06-16 11:07:24.811640: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 66 / 7717
# 	2025-06-16 11:07:24.823948: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 72 / 7717
# 	2025-06-16 11:07:24.852164: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 65 / 7717
# 	2025-06-16 11:07:24.864800: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 73 / 7717
# 	2025-06-16 11:07:24.893494: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 67 / 7717
# 	2025-06-16 11:07:24.897224: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 68 / 7717
# 	2025-06-16 11:07:24.901235: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 74 / 7717
# 	2025-06-16 11:07:24.907666: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 70 / 7717
# 	2025-06-16 11:07:24.935952: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 69 / 7717
# 	2025-06-16 11:07:24.951041: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 75 / 7717
# 	2025-06-16 11:07:24.972132: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 76 / 7717
# 	2025-06-16 11:07:24.996900: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 77 / 7717
# 	2025-06-16 11:07:25.008812: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 78 / 7717
# 	2025-06-16 11:07:25.053079: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 79 / 7717
# 	2025-06-16 11:07:25.088510: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 71 / 7717
# 	2025-06-16 11:07:25.091844: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 80 / 7717
# 	2025-06-16 11:07:25.099149: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 72 / 7717
# 	2025-06-16 11:07:25.116101: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 81 / 7717
# 	2025-06-16 11:07:25.127616: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 82 / 7717
# 	2025-06-16 11:07:25.147361: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 74 / 7717
# 	2025-06-16 11:07:25.172361: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 73 / 7717
# 	2025-06-16 11:07:25.209562: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 75 / 7717
# 	2025-06-16 11:07:25.261647: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 83 / 7717
# 	2025-06-16 11:07:25.277484: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 84 / 7717
# 	2025-06-16 11:07:25.300122: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 76 / 7717
# 	2025-06-16 11:07:25.310396: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 77 / 7717
# 	2025-06-16 11:07:25.322503: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 78 / 7717
# 	2025-06-16 11:07:25.346927: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 85 / 7717
# 	2025-06-16 11:07:25.356239: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 80 / 7717
# 	2025-06-16 11:07:25.362853: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 79 / 7717
# 	2025-06-16 11:07:25.364460: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 81 / 7717
# 	2025-06-16 11:07:25.374168: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 86 / 7717
# 	2025-06-16 11:07:25.383671: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 82 / 7717
# 	2025-06-16 11:07:25.394040: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 87 / 7717
# 	2025-06-16 11:07:25.445397: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 88 / 7717
# 	2025-06-16 11:07:25.501227: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 89 / 7717
# 	2025-06-16 11:07:25.508523: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 90 / 7717
# 	2025-06-16 11:07:25.531453: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 83 / 7717
# 	2025-06-16 11:07:25.551043: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 91 / 7717
# 	2025-06-16 11:07:25.566647: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 92 / 7717
# 	2025-06-16 11:07:25.569147: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 84 / 7717
# 	2025-06-16 11:07:25.576191: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 93 / 7717
# 	2025-06-16 11:07:25.582203: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 94 / 7717
# 	2025-06-16 11:07:25.585584: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 85 / 7717
# 	2025-06-16 11:07:25.639612: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 86 / 7717
# 	2025-06-16 11:07:25.690268: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 95 / 7717
# 	2025-06-16 11:07:25.727411: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 96 / 7717
# 	2025-06-16 11:07:25.754757: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 87 / 7717
# 	2025-06-16 11:07:25.758771: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 89 / 7717
# 	2025-06-16 11:07:25.763083: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 88 / 7717
# 	2025-06-16 11:07:25.773891: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 90 / 7717
# 	2025-06-16 11:07:25.803274: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 97 / 7717
# 	2025-06-16 11:07:25.825078: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 91 / 7717
# 	2025-06-16 11:07:25.835028: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 92 / 7717
# 	2025-06-16 11:07:25.841627: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 98 / 7717
# 	2025-06-16 11:07:25.866749: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 94 / 7717
# 	2025-06-16 11:07:25.912109: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 93 / 7717
# 	2025-06-16 11:07:25.918114: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 99 / 7717
# 	2025-06-16 11:07:25.938403: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 100 / 7717
# 	2025-06-16 11:07:25.948969: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 101 / 7717
# 	2025-06-16 11:07:25.952390: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 95 / 7717
# 	2025-06-16 11:07:25.965928: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 102 / 7717
# 	2025-06-16 11:07:25.979666: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 103 / 7717
# 	2025-06-16 11:07:26.012052: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 96 / 7717
# 	2025-06-16 11:07:26.017903: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 104 / 7717
# 	2025-06-16 11:07:26.019550: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 105 / 7717
# 	2025-06-16 11:07:26.090782: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 106 / 7717
# 	2025-06-16 11:07:26.099897: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 107 / 7717
# 	2025-06-16 11:07:26.145915: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 98 / 7717
# 	2025-06-16 11:07:26.164491: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 99 / 7717
# 	2025-06-16 11:07:26.196116: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 101 / 7717
# 	2025-06-16 11:07:26.199639: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 100 / 7717
# 	2025-06-16 11:07:26.210055: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 108 / 7717
# 	2025-06-16 11:07:26.212549: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 102 / 7717
# 	2025-06-16 11:07:26.222043: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 104 / 7717
# 	2025-06-16 11:07:26.296611: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 97 / 7717
# 	2025-06-16 11:07:26.297802: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 103 / 7717
# 	2025-06-16 11:07:26.303988: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 106 / 7717
# 	2025-06-16 11:07:26.332861: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 109 / 7717
# 	2025-06-16 11:07:26.345642: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 110 / 7717
# 	2025-06-16 11:07:26.380641: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 107 / 7717
# 	2025-06-16 11:07:26.382489: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 105 / 7717
# 	2025-06-16 11:07:26.391018: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 111 / 7717
# 	2025-06-16 11:07:26.392955: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 112 / 7717
# 	2025-06-16 11:07:26.408495: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 113 / 7717
# 	2025-06-16 11:07:26.437796: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 108 / 7717
# 	2025-06-16 11:07:26.469617: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 114 / 7717
# 	2025-06-16 11:07:26.478766: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 115 / 7717
# 	2025-06-16 11:07:26.481852: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 116 / 7717
# 	2025-06-16 11:07:26.510858: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 117 / 7717
# 	2025-06-16 11:07:26.513688: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 118 / 7717
# 	2025-06-16 11:07:26.588684: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 119 / 7717
# 	2025-06-16 11:07:26.594306: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 109 / 7717
# 	2025-06-16 11:07:26.628703: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 120 / 7717
# 	2025-06-16 11:07:26.647656: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 110 / 7717
# 	2025-06-16 11:07:26.672272: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 112 / 7717
# 	2025-06-16 11:07:26.722360: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 113 / 7717
# 	2025-06-16 11:07:26.731565: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 115 / 7717
# 	2025-06-16 11:07:26.736418: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 111 / 7717
# 	2025-06-16 11:07:26.738660: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 117 / 7717
# 	2025-06-16 11:07:26.760531: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 114 / 7717
# 	2025-06-16 11:07:26.785920: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 121 / 7717
# 	2025-06-16 11:07:26.803958: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 116 / 7717
# 	2025-06-16 11:07:26.822120: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 119 / 7717
# 	2025-06-16 11:07:26.849965: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...122 / 7717
# 	2025-06-16 11:07:26.851730: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 118 / 7717
# 	2025-06-16 11:07:26.852727: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
#
# 123 / 7717
# 	2025-06-16 11:07:26.895731: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 124 / 7717
# 	2025-06-16 11:07:26.916082: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 125 / 7717
# 	2025-06-16 11:07:26.921792: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 120 / 7717
# 	2025-06-16 11:07:26.925361: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 126 / 7717
# 	2025-06-16 11:07:26.926309: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 127 / 7717
# 	2025-06-16 11:07:26.942675: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 128 / 7717
# 	2025-06-16 11:07:26.964203: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 129 / 7717
# 	2025-06-16 11:07:26.995046: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 130 / 7717
# 	2025-06-16 11:07:27.034517: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 131 / 7717
# 	2025-06-16 11:07:27.037327: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 121 / 7717
# 	2025-06-16 11:07:27.042549: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 132 / 7717
# 	2025-06-16 11:07:27.101974: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 123 / 7717
# 	2025-06-16 11:07:27.127987: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 122 / 7717
# 	2025-06-16 11:07:27.153665: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 124 / 7717
# 	2025-06-16 11:07:27.165108: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 126 / 7717
# 	2025-06-16 11:07:27.169428: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 127 / 7717
# 	2025-06-16 11:07:27.170296: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 125 / 7717
# 	2025-06-16 11:07:27.210523: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 133 / 7717
# 	2025-06-16 11:07:27.218661: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 128 / 7717
# 	2025-06-16 11:07:27.271071: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 129 / 7717
# 	2025-06-16 11:07:27.279440: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 131 / 7717
# 	2025-06-16 11:07:27.299904: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 130 / 7717
# 	2025-06-16 11:07:27.301581: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 134 / 7717
# 	2025-06-16 11:07:27.312751: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 135 / 7717
# 	2025-06-16 11:07:27.339235: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 136 / 7717
# 	2025-06-16 11:07:27.351973: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 137 / 7717
# 	2025-06-16 11:07:27.356386: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 138 / 7717
# 	2025-06-16 11:07:27.357794: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 139 / 7717
# 	2025-06-16 11:07:27.395463: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 132 / 7717
# 	2025-06-16 11:07:27.399841: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 140 / 7717
# 	2025-06-16 11:07:27.466625: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 133 / 7717
# 	2025-06-16 11:07:27.475938: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 141 / 7717
# 	2025-06-16 11:07:27.480815: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 142 / 7717
# 	2025-06-16 11:07:27.504267: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 143 / 7717
# 	2025-06-16 11:07:27.509456: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 134 / 7717
# 	2025-06-16 11:07:27.553979: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 135 / 7717
# 	2025-06-16 11:07:27.581404: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 144 / 7717
# 	2025-06-16 11:07:27.582678: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 138 / 7717
# 	2025-06-16 11:07:27.603301: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 139 / 7717
# 	2025-06-16 11:07:27.639889: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 136 / 7717
# 	2025-06-16 11:07:27.643951: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 137 / 7717
# 	2025-06-16 11:07:27.647293: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 145 / 7717
# 	2025-06-16 11:07:27.674808: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 140 / 7717
# 	2025-06-16 11:07:27.728245: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 141 / 7717
# 	2025-06-16 11:07:27.737081: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 146 / 7717
# 	2025-06-16 11:07:27.754842: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 143 / 7717
# 	2025-06-16 11:07:27.763031: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 142 / 7717
# 	2025-06-16 11:07:27.764273: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 147 / 7717
# 	2025-06-16 11:07:27.771404: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 148 / 7717
# 	2025-06-16 11:07:27.784482: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 149 / 7717
# 	2025-06-16 11:07:27.824663: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 144 / 7717
# 	2025-06-16 11:07:27.826332: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 150 / 7717
# 	2025-06-16 11:07:27.833952: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 151 / 7717
# 	2025-06-16 11:07:27.836372: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 152 / 7717
# 	2025-06-16 11:07:27.918368: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 145 / 7717
# 	2025-06-16 11:07:27.937504: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 153 / 7717
# 	2025-06-16 11:07:27.939868: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 154 / 7717
# 	2025-06-16 11:07:27.949610: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 155 / 7717
# 	2025-06-16 11:07:27.959767: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 146 / 7717
# 	2025-06-16 11:07:28.004506: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 156 / 7717
# 	2025-06-16 11:07:28.018302: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 147 / 7717
# 	2025-06-16 11:07:28.021111: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 148 / 7717
# 	2025-06-16 11:07:28.025758: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 151 / 7717
# 	2025-06-16 11:07:28.093439: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 149 / 7717
# 	2025-06-16 11:07:28.132439: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 150 / 7717
# 	2025-06-16 11:07:28.135942: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 152 / 7717
# 	2025-06-16 11:07:28.163973: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 157 / 7717
# 	2025-06-16 11:07:28.168145: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 158 / 7717
# 	2025-06-16 11:07:28.200140: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 159 / 7717
# 	2025-06-16 11:07:28.201500: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 160 / 7717
# 	2025-06-16 11:07:28.220712: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 154 / 7717
# 	2025-06-16 11:07:28.230285: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 155 / 7717
# 	2025-06-16 11:07:28.249750: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 161 / 7717
# 	2025-06-16 11:07:28.263827: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 156 / 7717
# 	2025-06-16 11:07:28.270727: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 153 / 7717
# 	2025-06-16 11:07:28.273158: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 162 / 7717
# 	2025-06-16 11:07:28.309105: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 163 / 7717
# 	2025-06-16 11:07:28.324144: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 164 / 7717
# 	2025-06-16 11:07:28.344222: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 165 / 7717
# 	2025-06-16 11:07:28.408815: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 166 / 7717
# 	2025-06-16 11:07:28.434413: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 157 / 7717
# 	2025-06-16 11:07:28.444575: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 158 / 7717
# 	2025-06-16 11:07:28.463816: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 159 / 7717
# 	2025-06-16 11:07:28.464653: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 167 / 7717
# 	2025-06-16 11:07:28.469653: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 168 / 7717
# 	2025-06-16 11:07:28.475487: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 161 / 7717
# 	2025-06-16 11:07:28.505061: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 160 / 7717
# 	2025-06-16 11:07:28.523285: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 162 / 7717
# 	2025-06-16 11:07:28.557345: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 164 / 7717
# 	2025-06-16 11:07:28.578835: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 163 / 7717
# 	2025-06-16 11:07:28.605456: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 169 / 7717
# 	2025-06-16 11:07:28.624088: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 165 / 7717
# 	2025-06-16 11:07:28.646325: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 170 / 7717
# 	2025-06-16 11:07:28.655302: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 171 / 7717
# 	2025-06-16 11:07:28.656368: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 166 / 7717
# 	2025-06-16 11:07:28.679026: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 172 / 7717
# 	2025-06-16 11:07:28.688355: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 167 / 7717
# 	2025-06-16 11:07:28.714353: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 173 / 7717
# 	2025-06-16 11:07:28.719633: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 174 / 7717
# 	2025-06-16 11:07:28.743317: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 175 / 7717
# 	2025-06-16 11:07:28.761117: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 168 / 7717
# 	2025-06-16 11:07:28.766327: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 176 / 7717
# 	2025-06-16 11:07:28.784218: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 177 / 7717
# 	2025-06-16 11:07:28.828269: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 169 / 7717
# 	2025-06-16 11:07:28.869526: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...178 / 7717
# 	2025-06-16 11:07:28.870303: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
#
# 171 / 7717
# 	2025-06-16 11:07:28.894748: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 179 / 7717
# 	2025-06-16 11:07:28.908765: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 172 / 7717
# 	2025-06-16 11:07:28.933584: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 170 / 7717
# 	2025-06-16 11:07:28.934370: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 180 / 7717
# 	2025-06-16 11:07:28.952471: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 174 / 7717
# 	2025-06-16 11:07:28.984688: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 173 / 7717
# 	2025-06-16 11:07:29.006171: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 175 / 7717
# 	2025-06-16 11:07:29.026118: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 176 / 7717
# 	2025-06-16 11:07:29.032047: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 181 / 7717
# 	2025-06-16 11:07:29.049771: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 182 / 7717
# 	2025-06-16 11:07:29.071012: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 178 / 7717
# 	2025-06-16 11:07:29.098351: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 177 / 7717
# 	2025-06-16 11:07:29.113162: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 183 / 7717
# 	2025-06-16 11:07:29.121075: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 184 / 7717
# 	2025-06-16 11:07:29.125322: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 185 / 7717
# 	2025-06-16 11:07:29.161248: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 179 / 7717
# 	2025-06-16 11:07:29.166767: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 186 / 7717
# 	2025-06-16 11:07:29.199180: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 180 / 7717
# 	2025-06-16 11:07:29.202528: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 187 / 7717
# 	2025-06-16 11:07:29.220178: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 188 / 7717
# 	2025-06-16 11:07:29.241400: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 189 / 7717
# 	2025-06-16 11:07:29.277406: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 181 / 7717
# 	2025-06-16 11:07:29.281666: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 190 / 7717
# 	2025-06-16 11:07:29.284493: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 182 / 7717
# 	2025-06-16 11:07:29.303918: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 191 / 7717
# 	2025-06-16 11:07:29.351939: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 184 / 7717
# 	2025-06-16 11:07:29.365269: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 192 / 7717
# 	2025-06-16 11:07:29.377112: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 183 / 7717
# 	2025-06-16 11:07:29.410904: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 185 / 7717
# 	2025-06-16 11:07:29.418600: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 186 / 7717
# 	2025-06-16 11:07:29.433361: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 193 / 7717
# 	2025-06-16 11:07:29.464499: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 187 / 7717
# 	2025-06-16 11:07:29.473392: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 188 / 7717
# 	2025-06-16 11:07:29.475476: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 194 / 7717
# 	2025-06-16 11:07:29.482781: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 195 / 7717
# 	2025-06-16 11:07:29.549218: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 190 / 7717
# 	2025-06-16 11:07:29.575710: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 189 / 7717
# 	2025-06-16 11:07:29.581360: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 191 / 7717
# 	2025-06-16 11:07:29.592196: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 196 / 7717
# 	2025-06-16 11:07:29.597676: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 197 / 7717
# 	2025-06-16 11:07:29.603157: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 198 / 7717
# 	2025-06-16 11:07:29.620866: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 192 / 7717
# 	2025-06-16 11:07:29.649666: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 199 / 7717
# 	2025-06-16 11:07:29.667578: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 200 / 7717
# 	2025-06-16 11:07:29.671560: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 193 / 7717
# 	2025-06-16 11:07:29.733679: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 194 / 7717
# 	2025-06-16 11:07:29.737860: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 201 / 7717
# 	2025-06-16 11:07:29.765370: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 202 / 7717
# 	2025-06-16 11:07:29.772025: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 203 / 7717
# 	2025-06-16 11:07:29.779438: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 195 / 7717
# 	2025-06-16 11:07:29.794932: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 204 / 7717
# 	2025-06-16 11:07:29.825995: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 197 / 7717
# 	2025-06-16 11:07:29.856439: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 196 / 7717
# 	2025-06-16 11:07:29.858441: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 198 / 7717
# 	2025-06-16 11:07:29.870687: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 200 / 7717
# 	2025-06-16 11:07:29.908811: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 199 / 7717
# 	2025-06-16 11:07:29.910737: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 205 / 7717
# 	2025-06-16 11:07:29.925559: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 206 / 7717
# 	2025-06-16 11:07:29.928236: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 207 / 7717
# 	2025-06-16 11:07:29.977763: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 203 / 7717
# 	2025-06-16 11:07:30.025606: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 202 / 7717
# 	2025-06-16 11:07:30.030585: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 208 / 7717
# 	2025-06-16 11:07:30.051833: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 209 / 7717
# 	2025-06-16 11:07:30.056685: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 201 / 7717
# 	2025-06-16 11:07:30.060520: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 210 / 7717
# 	2025-06-16 11:07:30.066367: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 211 / 7717
# 	2025-06-16 11:07:30.121162: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 204 / 7717
# 	2025-06-16 11:07:30.123394: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 212 / 7717
# 	2025-06-16 11:07:30.126586: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 206 / 7717
# 	2025-06-16 11:07:30.199588: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 213 / 7717
# 	2025-06-16 11:07:30.214491: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 214 / 7717
# 	2025-06-16 11:07:30.230515: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 215 / 7717
# 	2025-06-16 11:07:30.244511: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 208 / 7717
# 	2025-06-16 11:07:30.309714: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 207 / 7717
# 	2025-06-16 11:07:30.316121: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 216 / 7717
# 	2025-06-16 11:07:30.326204: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 209 / 7717
# 	2025-06-16 11:07:30.328107: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 217 / 7717
# 	2025-06-16 11:07:30.371067: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 210 / 7717
# 	2025-06-16 11:07:30.381061: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 211 / 7717
# 	2025-06-16 11:07:30.386407: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 212 / 7717
# 	2025-06-16 11:07:30.423164: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 205 / 7717
# 	2025-06-16 11:07:30.450953: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 213 / 7717
# 	2025-06-16 11:07:30.480657: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 215 / 7717
# 	2025-06-16 11:07:30.498668: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 218 / 7717
# 	2025-06-16 11:07:30.512642: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 219 / 7717
# 	2025-06-16 11:07:30.516161: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 220 / 7717
# 	2025-06-16 11:07:30.523098: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 214 / 7717
# 	2025-06-16 11:07:30.545336: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 221 / 7717
# 	2025-06-16 11:07:30.567714: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 222 / 7717
# 	2025-06-16 11:07:30.578657: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 223 / 7717
# 	2025-06-16 11:07:30.615388: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 217 / 7717
# 	2025-06-16 11:07:30.634708: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 224 / 7717
# 	2025-06-16 11:07:30.642345: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 216 / 7717
# 	2025-06-16 11:07:30.653259: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 225 / 7717
# 	2025-06-16 11:07:30.667582: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 226 / 7717
# 	2025-06-16 11:07:30.675066: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 227 / 7717
# 	2025-06-16 11:07:30.725086: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 220 / 7717
# 	2025-06-16 11:07:30.776250: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 219 / 7717
# 	2025-06-16 11:07:30.777047: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 218 / 7717
# 	2025-06-16 11:07:30.786717: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 228 / 7717
# 	2025-06-16 11:07:30.818154: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 221 / 7717
# 	2025-06-16 11:07:30.832650: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 229 / 7717
# 	2025-06-16 11:07:30.837743: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 223 / 7717
# 	2025-06-16 11:07:30.868797: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 222 / 7717
# 	2025-06-16 11:07:30.874414: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 224 / 7717
# 	2025-06-16 11:07:30.913217: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 225 / 7717
# 	2025-06-16 11:07:30.917873: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 226 / 7717
# 	2025-06-16 11:07:30.945603: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 230 / 7717
# 	2025-06-16 11:07:30.955112: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 231 / 7717
# 	2025-06-16 11:07:30.968918: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 232 / 7717
# 	2025-06-16 11:07:30.975068: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 227 / 7717
# 	2025-06-16 11:07:30.979650: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 233 / 7717
# 	2025-06-16 11:07:31.030355: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 234 / 7717
# 	2025-06-16 11:07:31.063808: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 235 / 7717
# 	2025-06-16 11:07:31.080460: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 228 / 7717
# 	2025-06-16 11:07:31.082020: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 236 / 7717
# 	2025-06-16 11:07:31.089727: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 229 / 7717
# 	2025-06-16 11:07:31.094142: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 237 / 7717
# 	2025-06-16 11:07:31.104810: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 238 / 7717
# 	2025-06-16 11:07:31.128220: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 239 / 7717
# 	2025-06-16 11:07:31.173390: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 230 / 7717
# 	2025-06-16 11:07:31.191782: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 232 / 7717
# 	2025-06-16 11:07:31.263697: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 240 / 7717
# 	2025-06-16 11:07:31.271909: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 233 / 7717
# 	2025-06-16 11:07:31.274807: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 241 / 7717
# 	2025-06-16 11:07:31.285412: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 231 / 7717
# 	2025-06-16 11:07:31.309029: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 234 / 7717
# 	2025-06-16 11:07:31.309878: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 235 / 7717
# 	2025-06-16 11:07:31.329680: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 242 / 7717
# 	2025-06-16 11:07:31.363446: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 237 / 7717
# 	2025-06-16 11:07:31.373788: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 238 / 7717
# 	2025-06-16 11:07:31.374648: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 236 / 7717
# 	2025-06-16 11:07:31.386947: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 243 / 7717
# 	2025-06-16 11:07:31.434723: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 244 / 7717
# 	2025-06-16 11:07:31.461027: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 239 / 7717
# 	2025-06-16 11:07:31.462899: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 245 / 7717
# 	2025-06-16 11:07:31.490503: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 246 / 7717
# 	2025-06-16 11:07:31.495028: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 247 / 7717
# ...
# 2093 / 7717
# 	2025-06-16 11:08:46.238837: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2103 / 7717
# 	2025-06-16 11:08:46.271055: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2094 / 7717
# 	2025-06-16 11:08:46.283158: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2104 / 7717
# 	2025-06-16 11:08:46.288214: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2100 / 7717
# 	2025-06-16 11:08:46.295003: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2098 / 7717
# 	2025-06-16 11:08:46.302392: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2097 / 7717
# 	2025-06-16 11:08:46.311533: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2095 / 7717
# 	2025-06-16 11:08:46.331357: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2096 / 7717
# 	2025-06-16 11:08:46.333339: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2099 / 7717
# 	2025-06-16 11:08:46.373887: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2105 / 7717
# 	2025-06-16 11:08:46.426448: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2106 / 7717
# 	2025-06-16 11:08:46.471737: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2101 / 7717
# 	2025-06-16 11:08:46.482588: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2107 / 7717
# 	2025-06-16 11:08:46.490451: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2108 / 7717
# 	2025-06-16 11:08:46.492152: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2109 / 7717
# 	2025-06-16 11:08:46.510235: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2102 / 7717
# 	2025-06-16 11:08:46.525552: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2110 / 7717
# 	2025-06-16 11:08:46.532981: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2111 / 7717
# 	2025-06-16 11:08:46.534483: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2103 / 7717
# 	2025-06-16 11:08:46.554047: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2112 / 7717
# 	2025-06-16 11:08:46.570620: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2104 / 7717
# 	2025-06-16 11:08:46.592607: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2113 / 7717
# 	2025-06-16 11:08:46.669076: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2114 / 7717
# 	2025-06-16 11:08:46.720927: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2115 / 7717
# 	2025-06-16 11:08:46.748181: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2116 / 7717
# 	2025-06-16 11:08:46.768363: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2105 / 7717
# 	2025-06-16 11:08:46.788716: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2107 / 7717
# 	2025-06-16 11:08:46.813287: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2106 / 7717
# 	2025-06-16 11:08:46.815669: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2108 / 7717
# 	2025-06-16 11:08:46.817660: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2109 / 7717
# 	2025-06-16 11:08:46.823134: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2110 / 7717
# 	2025-06-16 11:08:46.829109: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2111 / 7717
# 	2025-06-16 11:08:46.832442: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2112 / 7717
# 	2025-06-16 11:08:46.869256: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2113 / 7717
# 	2025-06-16 11:08:46.929715: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2117 / 7717
# 	2025-06-16 11:08:46.974920: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2118 / 7717
# 	2025-06-16 11:08:46.993001: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2119 / 7717
# 	2025-06-16 11:08:46.997601: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2120 / 7717
# 	2025-06-16 11:08:47.004487: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2114 / 7717
# 	2025-06-16 11:08:47.005529: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2121 / 7717
# 	2025-06-16 11:08:47.010722: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2122 / 7717
# 	2025-06-16 11:08:47.016336: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2123 / 7717
# 	2025-06-16 11:08:47.020124: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2115 / 7717
# 	2025-06-16 11:08:47.024013: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2116 / 7717
# 	2025-06-16 11:08:47.049914: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2124 / 7717
# 	2025-06-16 11:08:47.059561: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2125 / 7717
# 	2025-06-16 11:08:47.112463: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2126 / 7717
# 	2025-06-16 11:08:47.214458: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2127 / 7717
# 	2025-06-16 11:08:47.226408: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2128 / 7717
# 	2025-06-16 11:08:47.261158: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2117 / 7717
# 	2025-06-16 11:08:47.311649: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2118 / 7717
# 	2025-06-16 11:08:47.340112: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2123 / 7717
# 	2025-06-16 11:08:47.343923: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2124 / 7717
# 	2025-06-16 11:08:47.363342: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2119 / 7717
# 	2025-06-16 11:08:47.364182: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2122 / 7717
# 	2025-06-16 11:08:47.371736: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2125 / 7717
# 	2025-06-16 11:08:47.379189: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2121 / 7717
# 	2025-06-16 11:08:47.380952: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2120 / 7717
# 	2025-06-16 11:08:47.396906: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2129 / 7717
# 	2025-06-16 11:08:47.486990: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2127 / 7717
# 	2025-06-16 11:08:47.513362: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2130 / 7717
# 	2025-06-16 11:08:47.520137: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2131 / 7717
# 	2025-06-16 11:08:47.521376: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2128 / 7717
# 	2025-06-16 11:08:47.526320: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2132 / 7717
# 	2025-06-16 11:08:47.534722: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2133 / 7717
# 	2025-06-16 11:08:47.538973: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2126 / 7717
# 	2025-06-16 11:08:47.545288: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2134 / 7717
# 	2025-06-16 11:08:47.553784: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2135 / 7717
# 	2025-06-16 11:08:47.558489: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2136 / 7717
# 	2025-06-16 11:08:47.564669: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2137 / 7717
# 	2025-06-16 11:08:47.573413: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2138 / 7717
# 	2025-06-16 11:08:47.687956: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2139 / 7717
# 	2025-06-16 11:08:47.705325: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2140 / 7717
# 	2025-06-16 11:08:47.732933: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2129 / 7717
# 	2025-06-16 11:08:47.754482: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2133 / 7717
# 	2025-06-16 11:08:47.856381: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2131 / 7717
# 	2025-06-16 11:08:47.863642: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2132 / 7717
# 	2025-06-16 11:08:47.867313: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2130 / 7717
# 	2025-06-16 11:08:47.872471: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2134 / 7717
# 	2025-06-16 11:08:47.879923: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2136 / 7717
# 	2025-06-16 11:08:47.911142: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2137 / 7717
# 	2025-06-16 11:08:47.915325: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2141 / 7717
# 	2025-06-16 11:08:47.922824: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2135 / 7717
# 	2025-06-16 11:08:47.926714: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2138 / 7717
# 	2025-06-16 11:08:47.974582: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2140 / 7717
# 	2025-06-16 11:08:48.016745: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2139 / 7717
# 	2025-06-16 11:08:48.030471: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2142 / 7717
# 	2025-06-16 11:08:48.033485: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2143 / 7717
# 	2025-06-16 11:08:48.038494: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2144 / 7717
# 	2025-06-16 11:08:48.051381: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2145 / 7717
# 	2025-06-16 11:08:48.055461: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2146 / 7717
# 	2025-06-16 11:08:48.077558: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2147 / 7717
# 	2025-06-16 11:08:48.083046: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2148 / 7717
# 	2025-06-16 11:08:48.108076: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2149 / 7717
# 	2025-06-16 11:08:48.155521: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2150 / 7717
# 	2025-06-16 11:08:48.175416: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2151 / 7717
# 	2025-06-16 11:08:48.193009: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2141 / 7717
# 	2025-06-16 11:08:48.204800: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2152 / 7717
# 	2025-06-16 11:08:48.212346: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2145 / 7717
# 	2025-06-16 11:08:48.358638: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2142 / 7717
# 	2025-06-16 11:08:48.360724: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2143 / 7717
# 	2025-06-16 11:08:48.364786: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2146 / 7717
# 	2025-06-16 11:08:48.376905: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2153 / 7717
# 	2025-06-16 11:08:48.382413: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2147 / 7717
# 	2025-06-16 11:08:48.385862: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2144 / 7717
# 	2025-06-16 11:08:48.428547: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2149 / 7717
# 	2025-06-16 11:08:48.449700: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2148 / 7717
# 	2025-06-16 11:08:48.460561: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2152 / 7717
# 	2025-06-16 11:08:48.472882: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2150 / 7717
# 	2025-06-16 11:08:48.479969: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2151 / 7717
# 	2025-06-16 11:08:48.480836: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2154 / 7717
# 	2025-06-16 11:08:48.544029: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2155 / 7717
# 	2025-06-16 11:08:48.562664: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2156 / 7717
# 	2025-06-16 11:08:48.564062: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2157 / 7717
# 	2025-06-16 11:08:48.565250: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2158 / 7717
# 	2025-06-16 11:08:48.570721: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2159 / 7717
# 	2025-06-16 11:08:48.610115: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2160 / 7717
# 	2025-06-16 11:08:48.639059: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2161 / 7717
# 	2025-06-16 11:08:48.644507: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2153 / 7717
# 	2025-06-16 11:08:48.645641: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2162 / 7717
# 	2025-06-16 11:08:48.652545: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2163 / 7717
# 	2025-06-16 11:08:48.671078: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2164 / 7717
# 	2025-06-16 11:08:48.707998: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2165 / 7717
# 	2025-06-16 11:08:48.826603: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2158 / 7717
# 	2025-06-16 11:08:48.870237: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2154 / 7717
# 	2025-06-16 11:08:48.884955: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2155 / 7717
# 	2025-06-16 11:08:48.902176: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2157 / 7717
# 	2025-06-16 11:08:48.931604: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2160 / 7717
# 	2025-06-16 11:08:48.938713: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2159 / 7717
# 	2025-06-16 11:08:48.947654: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2161 / 7717
# 	2025-06-16 11:08:48.950407: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2162 / 7717
# 	2025-06-16 11:08:48.952385: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2163 / 7717
# 	2025-06-16 11:08:48.960741: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2164 / 7717
# 	2025-06-16 11:08:48.971531: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2156 / 7717
# 	2025-06-16 11:08:48.973169: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2166 / 7717
# 	2025-06-16 11:08:49.045562: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2167 / 7717
# 	2025-06-16 11:08:49.070779: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2168 / 7717
# 	2025-06-16 11:08:49.079405: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2165 / 7717
# 	2025-06-16 11:08:49.102151: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2169 / 7717
# 	2025-06-16 11:08:49.116442: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2170 / 7717
# 	2025-06-16 11:08:49.119141: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2171 / 7717
# 	2025-06-16 11:08:49.141271: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2172 / 7717
# 	2025-06-16 11:08:49.144303: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2173 / 7717
# 	2025-06-16 11:08:49.145444: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2174 / 7717
# 	2025-06-16 11:08:49.149110: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2175 / 7717
# 	2025-06-16 11:08:49.153650: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2176 / 7717
# 	2025-06-16 11:08:49.163377: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2177 / 7717
# 	2025-06-16 11:08:49.288835: Colocalizing tblCHL_REP with ./data\tblFlombaum.csv ...
# 2167 / 7717
# 	2025-06-16 11:08:49.355415: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2168 / 7717
# 	2025-06-16 11:08:49.400802: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2166 / 7717
# 	2025-06-16 11:08:49.419462: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2170 / 7717
# 	2025-06-16 11:08:49.455096: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2171 / 7717
# 	2025-06-16 11:08:49.461106: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2169 / 7717
# 	2025-06-16 11:08:49.470091: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2173 / 7717
# 	2025-06-16 11:08:49.478679: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2172 / 7717
# 	2025-06-16 11:08:49.481583: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2174 / 7717
# 	2025-06-16 11:08:49.485309: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2176 / 7717
# 	2025-06-16 11:08:49.488469: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...
# 2175 / 7717
# 	2025-06-16 11:08:49.494297: Colocalizing tblAltimetry_REP with ./data\tblFlombaum.csv ...

# %%
#have an issue, see if I can work through the steps here to figure out whyb

# %%
#Stick some code below this spot as a holding zone, but put in a stop so the notebook doesn't try and run the bits as they may or may not work.

# %%
 raise SystemExit("Stop execution here")

# %%
import os, glob
import concurrent.futures
import pycmap
from config.config import API_KEY
from settings import DATA_DIR, COLOCALIZED_DIR
from common import halt, makedir, environmental_datasets
import pandas as pd
import datetime
from dateutil.parser import parse



def cyano_csv_files(cyanoDir):
    """
    Returns a list of path to csv files that hold observations of cyanobacteria.
    """
    return glob.glob(f"{cyanoDir}*.csv")


def add_env_columns(df, envs):
    """
    Adds new columns to the dataframe form each environmental variable.
    """
    for env in envs.values():
        for v in env.get("variables"):
            if v not in df.columns: df[v] = None
    return df

# %%
def add_env_temporal_coverage(api, envs):
    """
    Adds new entries to the envs dictionary indicating the temporal coverage of each environmental dataset.
    """
    for table, env in envs.items():
        df = api.query(f"SELECT MIN([time]) startTime, MAX([time]) endTime FROM {table}")
        if len(df) > 0:
            envs[table]["startTime"] = df.loc[0, "startTime"]
            envs[table]["endTime"] = df.loc[0, "endTime"]
    return envs

# %%
DATA_DIR = "./data/"           
cyanoFiles = cyano_csv_files(DATA_DIR)

# %%
cyanoFiles
# Out:
# ['./data\\tblD284_AMT15_Flow_Cytometry.csv',
#  './data\\tblD294_AMT16_Flow_Cytometry.csv',
#  './data\\tblD299_AMT17_Flow_Cytometry.csv',
#  './data\\tblD371_AMT21_flow_cytometry.csv',
#  './data\\tblDY110_AMT29_flow_cytometry.csv',
#  './data\\tblFlombaum.csv',
#  './data\\tblGlobal_PicoPhytoPlankton.csv',
#  './data\\tblJC039_AMT19_flow_cytometry.csv',
#  './data\\tblJC053_AMT20_flow_cytometry.csv',
#  './data\\tblJC079_AMT22_flow_cytometry.csv',
#  './data\\tblJR15001_AMT25_flow_cytometry.csv',
#  './data\\tblJR19980514_AMT06_Flow_Cytometry.csv',
#  './data\\tblJR20030512_AMT12_Flow_Cytometry.csv',
#  './data\\tblJR20030910_AMT13_Flow_Cytometry.csv',
#  './data\\tblJR20040428_AMT14_Flow_Cytometry.csv',
#  './data\\tblJR20081003_AMT18_flow_cytometry.csv',
#  './data\\tblJR20131005_AMT23_flow_cytometry.csv',
#  './data\\tblJR20140922_AMT24_flow_cytometry.csv',
#  './data\\tblSeaFlow_v1_5.csv']

# %%
    api = pycmap.API(token=API_KEY)
    makedir(COLOCALIZED_DIR)
    envs = environmental_datasets()

# %%
#this adds time information to an existing envs dictionary
envs = add_env_temporal_coverage(api, envs)

# %%
envs
# Out:
# {'tblSST_AVHRR_OI_NRT': {'variables': ['sst'],
#   'tolerances': [1, 0.25, 0.25, 5],
#   'hasDepth': False,
#   'isClimatology': False,
#   'startTime': '1981-09-01T00:00:00.000Z',
#   'endTime': '2025-06-10T00:00:00.000Z'},
#  'tblCHL_REP': {'variables': ['chl'],
#   'tolerances': [4, 0.25, 0.25, 5],
#   'hasDepth': False,
#   'isClimatology': False,
#   'startTime': '1998-01-01T00:00:00.000Z',
#   'endTime': '2018-06-26T00:00:00.000Z'},
#  'tblSSS_NRT': {'variables': ['sss'],
#   'tolerances': [1, 0.25, 0.25, 5],
#   'hasDepth': False,
#   'isClimatology': False,
#   'startTime': '2015-03-31T00:00:00.000Z',
#   'endTime': '2022-05-01T00:00:00.000Z'},
#  'tblModis_PAR': {'variables': ['PAR'],
#   'tolerances': [1, 0.25, 0.25, 5],
#   'hasDepth': False,
#   'isClimatology': False,
#   'startTime': '2010-01-01T00:00:00.000Z',
#   'endTime': '2022-03-07T00:00:00.000Z'},
#  'tblAltimetry_REP': {'variables': ['sla', 'adt', 'ugosa', 'vgosa'],
#   'tolerances': [1, 0.25, 0.25, 5],
#   'hasDepth': False,
#   'isClimatology': False},
#  'tblPisces_NRT': {'variables': ['NO3', 'PO4', 'Fe', 'O2', 'Si', 'PP'],
#   'tolerances': [4, 0.5, 0.5, 5],
#   'hasDepth': True,
#   'isClimatology': False,
#   'startTime': '2011-12-31T00:00:00.000Z',
#   'endTime': '2019-04-27T00:00:00.000Z'},
#  'tblWOA_Climatology': {'variables': ['density_WOA_clim',
#    'salinity_WOA_clim',
#    'nitrate_WOA_clim',
#    'phosphate_WOA_clim',
#    'silicate_WOA_clim',
#    'oxygen_WOA_clim'],
#   'tolerances': [1, 0.75, 0.75, 5],
#   'hasDepth': True,
#   'isClimatology': True}}

# %%
cyanoFiles
# Out:
# ['./data\\tblD284_AMT15_Flow_Cytometry.csv',
#  './data\\tblD294_AMT16_Flow_Cytometry.csv',
#  './data\\tblD299_AMT17_Flow_Cytometry.csv',
#  './data\\tblD371_AMT21_flow_cytometry.csv',
#  './data\\tblDY110_AMT29_flow_cytometry.csv',
#  './data\\tblFlombaum.csv',
#  './data\\tblGlobal_PicoPhytoPlankton.csv',
#  './data\\tblJC039_AMT19_flow_cytometry.csv',
#  './data\\tblJC053_AMT20_flow_cytometry.csv',
#  './data\\tblJC079_AMT22_flow_cytometry.csv',
#  './data\\tblJR15001_AMT25_flow_cytometry.csv',
#  './data\\tblJR19980514_AMT06_Flow_Cytometry.csv',
#  './data\\tblJR20030512_AMT12_Flow_Cytometry.csv',
#  './data\\tblJR20030910_AMT13_Flow_Cytometry.csv',
#  './data\\tblJR20040428_AMT14_Flow_Cytometry.csv',
#  './data\\tblJR20081003_AMT18_flow_cytometry.csv',
#  './data\\tblJR20131005_AMT23_flow_cytometry.csv',
#  './data\\tblJR20140922_AMT24_flow_cytometry.csv',
#  './data\\tblSeaFlow_v1_5.csv']

# %%
cyanoFile = cyanoFiles[1]
df = pd.read_csv(cyanoFile)
df = add_env_columns(df, envs)
dfs = [df.loc[i].to_frame().T for i in range(len(df))]

# %%
colocalizedDF  = pd.DataFrame({})

# %%
def match(df, api, envs, cyanoFile, rowCount):
    """
    Takes a single-row dataframe containing cyano observations and colocalizes with the 
    environmental variables included in the `envs` argument. The tolerance parametrs 
    are also included in the `envs` argument.
    """ 
    def get_month(dt):
        return parse(dt).month

    def shift_dt(dt, delta):
        delta = float(delta)
        dt = parse(dt)
        dt += datetime.timedelta(days=delta)
        return dt.strftime("%Y-%m-%d %H:%M:%S")

    def in_time_window(sourceDT, targetMinDT, targetMaxDT):
        targetMinDT = targetMinDT.split(".000Z")[0]
        targetMaxDT = targetMaxDT.split(".000Z")[0]
        return not (
                    parse(sourceDT) < parse(targetMinDT) or 
                    parse(sourceDT) > parse(targetMaxDT)
                    )

    def construc_query(table, env, t, lat, lon, depth):
        variables = env["variables"] 
        timeTolerance = env["tolerances"][0] 
        latTolerance = env["tolerances"][1] 
        lonTolerance = env["tolerances"][2]  
        depthTolerance = env["tolerances"][3]  
        hasDepth = env["hasDepth"] 
        isClimatology = env["isClimatology"]
        inTimeRange = True
        if not isClimatology:
            startTime = env["startTime"] #issue here, KeyError 'startTime'
            endTime = env["endTime"]    
            inTimeRange = in_time_window(t, startTime, endTime)
        selectClause = "SELECT " + ", ".join([f"AVG({v}) {v}" for v in variables]) + " FROM " + table
        timeClause = f" WHERE [time] BETWEEN '{shift_dt(t, -timeTolerance)}' AND '{shift_dt(t, timeTolerance)}' "
        if not inTimeRange or isClimatology: timeClause = f" WHERE [month]={get_month(t)} "
        latClause = f" AND lat BETWEEN {lat-latTolerance} AND {lat+latTolerance} "
        lonClause = f" AND lon BETWEEN {lon-lonTolerance} AND {lon+lonTolerance} "
        depthClause = f" AND depth BETWEEN {depth-depthTolerance} AND {depth+depthTolerance} "
        if not hasDepth: depthClause = ""                
        return selectClause + timeClause + latClause + lonClause + depthClause        


    if len(df) != 1: halt(f"Invalid dataframe input.\nExpected a single row dataframe but received {len(df)} rows.")
    rowIndex = df.index.values[0]
    df.reset_index(drop=True, inplace=True)
    t= df.iloc[0]["time"]
    lat = df.iloc[0]["lat"]
    lon = df.iloc[0]["lon"] 
    depth = 0
    if 'depth' in df.columns: depth = df.iloc[0]["depth"]
    for table, env in envs.items():
        print(f"{rowIndex} / {rowCount-1}\n\t{datetime.datetime.now()}: Colocalizing {table} with {cyanoFile} ...")
        query = construc_query(table, env, t, lat, lon, depth)
        matchedEnv = api.query(query)
        if len(matchedEnv)>0:
            for v in env["variables"]: df.at[0, v] = matchedEnv.iloc[0][v] 
    return df

# %%
def get_month(dt):
    return parse(dt).month

def shift_dt(dt, delta):
    delta = float(delta)
    dt = parse(dt)
    dt += datetime.timedelta(days=delta)
    return dt.strftime("%Y-%m-%d %H:%M:%S")

def in_time_window(sourceDT, targetMinDT, targetMaxDT):
    targetMinDT = targetMinDT.split(".000Z")[0]
    targetMaxDT = targetMaxDT.split(".000Z")[0]
    return not (
                parse(sourceDT) < parse(targetMinDT) or 
                parse(sourceDT) > parse(targetMaxDT)
                )

# %%
def construc_query(table, env, t, lat, lon, depth):
    variables = env["variables"] 
    timeTolerance = env["tolerances"][0] 
    latTolerance = env["tolerances"][1] 
    lonTolerance = env["tolerances"][2]  
    depthTolerance = env["tolerances"][3]  
    hasDepth = env["hasDepth"] 
    isClimatology = env["isClimatology"]
    inTimeRange = True
    if not isClimatology:
        startTime = env["startTime"] #issue here, KeyError 'startTime'
        endTime = env["endTime"]    
        inTimeRange = in_time_window(t, startTime, endTime)
    selectClause = "SELECT " + ", ".join([f"AVG({v}) {v}" for v in variables]) + " FROM " + table
    timeClause = f" WHERE [time] BETWEEN '{shift_dt(t, -timeTolerance)}' AND '{shift_dt(t, timeTolerance)}' "
    if not inTimeRange or isClimatology: timeClause = f" WHERE [month]={get_month(t)} "
    latClause = f" AND lat BETWEEN {lat-latTolerance} AND {lat+latTolerance} "
    lonClause = f" AND lon BETWEEN {lon-lonTolerance} AND {lon+lonTolerance} "
    depthClause = f" AND depth BETWEEN {depth-depthTolerance} AND {depth+depthTolerance} "
    if not hasDepth: depthClause = ""                
    return selectClause + timeClause + latClause + lonClause + depthClause

# %%
envs.items()
# Out:
# dict_items([('tblSST_AVHRR_OI_NRT', {'variables': ['sst'], 'tolerances': [1, 0.25, 0.25, 5], 'hasDepth': False, 'isClimatology': False, 'startTime': '1981-09-01T00:00:00.000Z', 'endTime': '2025-06-10T00:00:00.000Z'}), ('tblCHL_REP', {'variables': ['chl'], 'tolerances': [4, 0.25, 0.25, 5], 'hasDepth': False, 'isClimatology': False, 'startTime': '1998-01-01T00:00:00.000Z', 'endTime': '2018-06-26T00:00:00.000Z'}), ('tblSSS_NRT', {'variables': ['sss'], 'tolerances': [1, 0.25, 0.25, 5], 'hasDepth': False, 'isClimatology': False, 'startTime': '2015-03-31T00:00:00.000Z', 'endTime': '2022-05-01T00:00:00.000Z'}), ('tblModis_PAR', {'variables': ['PAR'], 'tolerances': [1, 0.25, 0.25, 5], 'hasDepth': False, 'isClimatology': False, 'startTime': '2010-01-01T00:00:00.000Z', 'endTime': '2022-03-07T00:00:00.000Z'}), ('tblAltimetry_REP', {'variables': ['sla', 'adt', 'ugosa', 'vgosa'], 'tolerances': [1, 0.25, 0.25, 5], 'hasDepth': False, 'isClimatology': False}), ('tblPisces_NRT', {'variables': ['NO3', 'PO4', 'Fe', 'O2', 'Si', 'PP'], 'tolerances': [4, 0.5, 0.5, 5], 'hasDepth': True, 'isClimatology': False, 'startTime': '2011-12-31T00:00:00.000Z', 'endTime': '2019-04-27T00:00:00.000Z'}), ('tblWOA_Climatology', {'variables': ['density_WOA_clim', 'salinity_WOA_clim', 'nitrate_WOA_clim', 'phosphate_WOA_clim', 'silicate_WOA_clim', 'oxygen_WOA_clim'], 'tolerances': [1, 0.75, 0.75, 5], 'hasDepth': True, 'isClimatology': True})])

# %%
env
# Out:
# {'variables': ['sst'],
#  'tolerances': [1, 0.25, 0.25, 5],
#  'hasDepth': False,
#  'isClimatology': False,
#  'startTime': '1981-09-01T00:00:00.000Z',
#  'endTime': '2025-06-10T00:00:00.000Z'}

# %%
env["startTime"]
# Out:
# '1981-09-01T00:00:00.000Z'

# %%
pip install debugger
# Out:
# Collecting debugger
#   Downloading debugger-1.3.tar.gz (2.7 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: debugger
#   Building wheel for debugger (setup.py): started
#   Building wheel for debugger (setup.py): finished with status 'done'
#   Created wheel for debugger: filename=debugger-1.3-py3-none-any.whl size=3347 sha256=0f6708047f34dbd0085b07dfcebb2b51a54eea836702bf50ee5055e096ef9e61
#   Stored in directory: c:\users\klongnecker\appdata\local\pip\cache\wheels\bf\2c\13\dfcf58c96fc0f83b1c06d6c356485417a3ba1a7acfdd73da13
# Successfully built debugger
# Installing collected packages: debugger
# Successfully installed debugger-1.3
# Note: you may need to restart the kernel to use updated packages.

# %%
#this will make a file with everything: data/compiled/compiled.csv 
# %run compiler.py
# Out:
#             ##########################################################
#             #                                                        #
#             #                                                        #
#             #         Compiling Colocalized Cyano Datasets           #
#             #                                                        #
#             #                                                        #
#             ##########################################################
